# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from flowprintOptimal.sekigo.core.flowConfig import FlowConfig
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from flowprintOptimal.sekigo.flowUtils.commons import loadFlows, saveFlows
from flowprintOptimal.sekigo.flowUtils.sampler import FixedLengthSampler, FixedLengthSimpleSampler
from flowprintOptimal.sekigo.core.flowRepresentation import FlowRepresentation
from typing import List
from flowprintOptimal.sekigo.flowUtils.flowDatasets import MaxNormalizedDataset,ActivityDataset,BaseFlowDataset,DDQNActivityDataset
from flowprintOptimal.sekigo.dataAnalysis.vNATDataFrameProcessor import VNATDataFrameProcessor
from flowprintOptimal.sekigo.flowUtils.commons import getValidInvalidStartingPointsForSubFlowStart, getActivityArrayFromFlow
from flowprintOptimal.sekigo.modeling.neuralNetworks import LSTMNetwork,TransformerGenerator,CNNNetwork1D
from flowprintOptimal.sekigo.modeling.loggers import Logger
from sklearn.ensemble import RandomForestClassifier
from torch.utils.data import Dataset, DataLoader,WeightedRandomSampler
from tqdm import tqdm
from copy import deepcopy
import matplotlib.pyplot as plt
from joblib import delayed, Parallel
from typing import List
from flowprintOptimal.sekigo.earlyClassification.DQL.memoryFiller import MemoryFiller
from flowprintOptimal.sekigo.earlyClassification.DQL.core import MemoryElement,Rewarder,State
from flowprintOptimal.sekigo.earlyClassification.DQL.datasets import MemoryDataset
from torch.nn.utils.rnn import pack_sequence, unpack_sequence
from flowprintOptimal.sekigo.dataAnalysis.dataFrameProcessor import SoftwareUpdateDataProcessor,GamingDownloadDataFrameProcessor
from flowprintOptimal.sekigo.dataAnalysis.dataFrameExtractor import DataFrameExtractor
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,  ConfusionMatrixDisplay
from flowprintOptimal.sekigo.earlyClassification.DQL.trainers import EarlyClassificationtrainer
from flowprintOptimal.sekigo.modeling.neuralNetworks import LinearPredictor
import warnings
from flowprintOptimal.sekigo.utils.commons import augmentData
warnings.filterwarnings('ignore')
import torch.nn.functional as F
import random
from flowprintOptimal.sekigo.modeling.trainers import NNClassificationTrainer

# %%
flow_config = FlowConfig(grain= 1, band_thresholds= [1250])
processor1 = SoftwareUpdateDataProcessor(parquet_path= "data/software-update-1w.parquet")
processor2 = GamingDownloadDataFrameProcessor(parquet_path= "data/2023-12-01--2023-12-31--flowprint.parquet")
flows = DataFrameExtractor.getData(data_frame_processors= [processor2,processor1],needed_flow_config= flow_config)
class_type_filtered_flows = flows
FT_filtered_flows = list(filter(lambda x : x.class_type != "Download",class_type_filtered_flows))
FT_flows = list(filter(lambda x : x.class_type == "Download",class_type_filtered_flows))
len(FT_filtered_flows) + len(FT_flows) == len(class_type_filtered_flows)

# %%
flows = loadFlows(path= "data/VNAT/flowStore/vnatflowshalfsecond_2_bands.json")
class_type_filtered_flows = VNATDataFrameProcessor.convertLabelsToTopLevel(flows)
FT_filtered_flows = list(filter(lambda x : x.class_type != "FT",class_type_filtered_flows))
FT_flows = list(filter(lambda x : x.class_type == "FT",class_type_filtered_flows))
len(FT_filtered_flows) + len(FT_flows) == len(class_type_filtered_flows)
# Out:
# True

# %%
sampler = FixedLengthSampler(flow_config= FT_filtered_flows[0].flow_config,required_length_in_seconds = 30,ratio_of_median_to_sample= .1,min_activity_for_start_point= 25,sample_wise_train_ratio= .8, temporal_train_ratio= 1)
FT_filtered_split_flows = sampler.sampleAndCutToLength(data= FT_filtered_flows)
ft_sampler = FixedLengthSampler(flow_config= FT_filtered_flows[0].flow_config,required_length_in_seconds = 30,ratio_of_median_to_sample= .5,min_activity_for_start_point= 25,sample_wise_train_ratio= 1, temporal_train_ratio= 1)
FT_split_flows = ft_sampler.sampleAndCutToLength(data= FT_flows)
all_sampler = FixedLengthSampler(flow_config= class_type_filtered_flows[0].flow_config,required_length_in_seconds = 30,ratio_of_median_to_sample= .1,min_activity_for_start_point= 25,sample_wise_train_ratio= .8, temporal_train_ratio= 1)
all_flows = all_sampler.sampleAndCutToLength(data= class_type_filtered_flows)
# Out:
# {'chat': 0.009890938699667779, 'control': 0.1760825125441368, 'streaming': 0.09997625893587275}
# overlapping points = 0
# {'FT': 0.4996028594122319}
# overlapping points = 0
# {'FT': 1, 'chat': 0.054945599837151825, 'control': 0.9781639100538934, 'streaming': 0.5553826268168509}
# overlapping points = 0

# %%
print(pd.Series(map(lambda x : x.class_type,FT_filtered_split_flows["train_flows"])).value_counts())
print(pd.Series(map(lambda x : x.class_type,FT_filtered_split_flows["test_flows"])).value_counts())
print(pd.Series(map(lambda x : x.class_type,all_flows["train_flows"])).value_counts())
print(pd.Series(map(lambda x : x.class_type,all_flows["test_flows"])).value_counts())
print(pd.Series(map(lambda x : x.class_type,FT_split_flows["train_flows"])).value_counts())
#print(pd.Series(map(lambda x : x.class_type,FT_split_flows["test_flows"])).value_counts())
# Out:
# streaming    3451
# chat         3274
# control      2633
# Name: count, dtype: int64
# control      1367
# streaming     630
# chat          573
# Name: count, dtype: int64
# streaming    17451
# chat         16007
# control      14749
# FT            1066
# Name: count, dtype: int64
# control      6420
# chat         5113
# streaming    3805
# FT            193
# Name: count, dtype: int64
# FT    634
# Name: count, dtype: int64

# %%
class DDQNActivityDataset(BaseFlowDataset):
    def __init__(self, flows: List[FlowRepresentation], label_to_index: dict,do_aug = False,balance = False):
        super().__init__(flows = flows, label_to_index= label_to_index)
        self.do_aug = do_aug
        self.labels = list(map(lambda x : self.label_to_index[x.class_type],self.flows))
        self.flows = list(map(lambda x : getActivityArrayFromFlow(x), self.flows))

        if balance == True:
            print("balancing")
            self.cureImbalance()
    
    def __getitem__(self, index):
        return dict(data = self.flows[index] if (self.do_aug == False) else augmentData(self.flows[index],fraction_range= [0,.1]), label  = self.labels[index])
    
    def cureImbalance(self):
        
        label_to_indices = dict()
        for i,label in enumerate(self.labels):
            if label not in label_to_indices:
                label_to_indices[label] = []
            label_to_indices[label].append(i)
        
        
        counts = [len(x) for _,x in label_to_indices.items()]
        max_counts = max(counts)
        print(counts)
        added_flows,added_labels = [],[]
        for label,indices in label_to_indices.items():
            to_add = max_counts - len(indices)
            if to_add > 0:
                replication_indices = random.choices(population= indices,k= to_add)
            
                for replication_index in replication_indices:
                    added_flows.append(self.flows[replication_index].copy())
                    added_labels.append(self.labels[replication_index])
        


        self.flows.extend(added_flows)
        self.labels.extend(added_labels)

# %%
all_train_dataset = DDQNActivityDataset(flows= all_flows["train_flows"],label_to_index= None,do_aug= False,balance= False)
all_test_dataset = DDQNActivityDataset(flows = all_flows["test_flows"], label_to_index= all_train_dataset.label_to_index)
train_dataset = DDQNActivityDataset(flows= FT_filtered_split_flows["train_flows"],label_to_index= None,do_aug= False)
test_dataset = DDQNActivityDataset(flows= FT_filtered_split_flows["test_flows"],label_to_index= train_dataset.label_to_index)
ood_dataset = DDQNActivityDataset(flows= FT_split_flows["train_flows"],label_to_index= None)
#ood_support_dataset = DDQNActivityDataset(flows= FT_split_flows["train_flows"],label_to_index= ood_dataset.label_to_index)

# %%
classifier_ = CNNNetwork1D(in_channels= 6,num_filters= 32,output_dims= [len(all_train_dataset.label_to_index)],num_layers= 3)#LSTMNetwork(lstm_hidden_size= 64,lstm_input_size=6,output_dim = len(all_train_dataset.label_to_index))
logger= Logger(name= "classification",verbose= True)
logger.default_step_size = 500
classification_trainer = NNClassificationTrainer(classifier = classifier_,device= device,logger= logger)
classification_trainer.train(train_dataset= all_train_dataset,test_dataset= all_test_dataset,epochs=20,batch_size= 64,lr= .0001)
# Out:
# classification ---- 1 metric test_f1 = 0.006137115237852963
# classification ---- 1 metric train_f1 = 0.010588211923160968
# classification ---- 10 metric train_loss = 1.3990599036216735
# classification ---- 20 metric train_loss = 1.38609139919281
# classification ---- 30 metric train_loss = 1.377616274356842
# classification ---- 40 metric train_loss = 1.3585224151611328
# classification ---- 50 metric train_loss = 1.2981319785118104
# classification ---- 60 metric train_loss = 1.1943374276161194
# classification ---- 70 metric train_loss = 1.1328577995300293
# classification ---- 80 metric train_loss = 1.1128541469573974
# classification ---- 90 metric train_loss = 1.0744221568107606
# classification ---- 100 metric train_loss = 1.0778009116649627
# classification ---- 110 metric train_loss = 1.0252083241939545
# classification ---- 120 metric train_loss = 0.989182960987091
# classification ---- 130 metric train_loss = 0.9135378539562226
# classification ---- 140 metric train_loss = 0.8773638248443604
# classification ---- 150 metric train_loss = 0.747443026304245
# classification ---- 160 metric train_loss = 0.6377316594123841
# classification ---- 170 metric train_loss = 0.5709991931915284
# classification ---- 180 metric train_loss = 0.5564748108386993
# classification ---- 190 metric train_loss = 0.4909842640161514
# classification ---- 200 metric train_loss = 0.5111259341239929
# classification ---- 210 metric train_loss = 0.42919667065143585
# classification ---- 220 metric train_loss = 0.4456953853368759
# classification ---- 230 metric train_loss = 0.38769064247608187
# classification ---- 240 metric train_loss = 0.3884963393211365
# classification ---- 250 metric train_loss = 0.35275293737649915
# classification ---- 260 metric train_loss = 0.34677063673734665
# classification ---- 270 metric train_loss = 0.31781286001205444
# classification ---- 280 metric train_loss = 0.33171568661928175
# classification ---- 290 metric train_loss = 0.27025009244680404
# classification ---- 300 metric train_loss = 0.2659512385725975
# classification ---- 310 metric train_loss = 0.2628948390483856
# classification ---- 320 metric train_loss = 0.20248987525701523
# classification ---- 330 metric train_loss = 0.2864163532853127
# classification ---- 340 metric train_loss = 0.18858899921178818
# classification ---- 350 metric train_loss = 0.1903465449810028
# classification ---- 360 metric train_loss = 0.17071399390697478
# classification ---- 370 metric train_loss = 0.20950533598661422
# classification ---- 380 metric train_loss = 0.20715411454439164
# classification ---- 390 metric train_loss = 0.17764069586992265
# classification ---- 400 metric train_loss = 0.18180355429649353
# classification ---- 410 metric train_loss = 0.23796667233109475
# classification ---- 420 metric train_loss = 0.17056114822626114
# classification ---- 430 metric train_loss = 0.1908555082976818
# classification ---- 440 metric train_loss = 0.16511000990867614
# classification ---- 450 metric train_loss = 0.13520141020417215
# classification ---- 460 metric train_loss = 0.12969543412327766
# classification ---- 470 metric train_loss = 0.13259975612163544
# classification ---- 480 metric train_loss = 0.15783110037446021
# classification ---- 490 metric train_loss = 0.13809222243726255
# classification ---- 500 metric train_loss = 0.12918188720941542
# classification ---- 2 metric test_f1 = 0.6993425603770554
# classification ---- 510 metric train_loss = 0.12588278986513615
# classification ---- 520 metric train_loss = 0.0971927024424076
# classification ---- 530 metric train_loss = 0.11373500786721706
# classification ---- 540 metric train_loss = 0.0895499862730503
# classification ---- 550 metric train_loss = 0.10582918114960194
# classification ---- 560 metric train_loss = 0.11198224555701017
# classification ---- 570 metric train_loss = 0.15088738426566123
# classification ---- 580 metric train_loss = 0.12603917755186558
# classification ---- 590 metric train_loss = 0.11047081500291825
# classification ---- 600 metric train_loss = 0.09310035854578018
# classification ---- 610 metric train_loss = 0.10250496938824653
# classification ---- 620 metric train_loss = 0.10101570002734661
# classification ---- 630 metric train_loss = 0.14571370109915732
# classification ---- 640 metric train_loss = 0.0803431086242199
# classification ---- 650 metric train_loss = 0.10039620436728
# classification ---- 660 metric train_loss = 0.09452494736760855
# classification ---- 670 metric train_loss = 0.09874509256333112
# classification ---- 680 metric train_loss = 0.08316226601600647
# classification ---- 690 metric train_loss = 0.058708364702761175
# classification ---- 700 metric train_loss = 0.08045807387679815
# classification ---- 710 metric train_loss = 0.10898627415299415
# classification ---- 720 metric train_loss = 0.08864291794598103
# classification ---- 730 metric train_loss = 0.15078332666307687
# classification ---- 740 metric train_loss = 0.09965639971196652
# classification ---- 750 metric train_loss = 0.06571009084582329
# classification ---- 760 metric train_loss = 0.1300574690103531
# classification ---- 770 metric train_loss = 0.06542514152824878
# classification ---- 780 metric train_loss = 0.05954615380614996
# classification ---- 790 metric train_loss = 0.055072454176843165
# classification ---- 800 metric train_loss = 0.087455041334033
# classification ---- 810 metric train_loss = 0.08654434215277433
# classification ---- 820 metric train_loss = 0.12329461202025413
# classification ---- 830 metric train_loss = 0.09041316099464894
# classification ---- 840 metric train_loss = 0.0738998856395483
# classification ---- 850 metric train_loss = 0.07363216690719128
# classification ---- 860 metric train_loss = 0.06599289709702134
# classification ---- 870 metric train_loss = 0.08620591200888157
# classification ---- 880 metric train_loss = 0.08770610969513655
# classification ---- 890 metric train_loss = 0.1376666497439146
# classification ---- 900 metric train_loss = 0.04736809944733977
# classification ---- 910 metric train_loss = 0.09836715422570705
# classification ---- 920 metric train_loss = 0.0796210752800107
# classification ---- 930 metric train_loss = 0.05243610516190529
# classification ---- 940 metric train_loss = 0.050514172203838824
# classification ---- 950 metric train_loss = 0.0713452685624361
# classification ---- 960 metric train_loss = 0.06123390132561326
# classification ---- 970 metric train_loss = 0.06465720254927873
# classification ---- 980 metric train_loss = 0.06184498779475689
# classification ---- 990 metric train_loss = 0.0469471032731235
# classification ---- 1000 metric train_loss = 0.07609945088624955
# classification ---- 3 metric test_f1 = 0.9447364982782358
# classification ---- 2 metric train_f1 = 0.9410855430393412
# classification ---- 1010 metric train_loss = 0.06829469371587038
# classification ---- 1020 metric train_loss = 0.0434117553755641
# classification ---- 1030 metric train_loss = 0.07895211335271597
# classification ---- 1040 metric train_loss = 0.04419401159975678
# classification ---- 1050 metric train_loss = 0.03952372847124934
# classification ---- 1060 metric train_loss = 0.05955051649361849
# classification ---- 1070 metric train_loss = 0.0552562041208148
# classification ---- 1080 metric train_loss = 0.06796705699525774
# classification ---- 1090 metric train_loss = 0.05359060419723392
# classification ---- 1100 metric train_loss = 0.09426158629357814
# classification ---- 1110 metric train_loss = 0.03858279418200254
# classification ---- 1120 metric train_loss = 0.07664907788857818
# classification ---- 1130 metric train_loss = 0.06354994606226683
# classification ---- 1140 metric train_loss = 0.07937679020687938
# classification ---- 1150 metric train_loss = 0.04231930738314986
# classification ---- 1160 metric train_loss = 0.05555746089667082
# classification ---- 1170 metric train_loss = 0.04159123199060559
# classification ---- 1180 metric train_loss = 0.048733345977962014
# classification ---- 1190 metric train_loss = 0.0600285554304719
# classification ---- 1200 metric train_loss = 0.061709259357303384
# classification ---- 1210 metric train_loss = 0.044971381314098835
# classification ---- 1220 metric train_loss = 0.052920001838356254
# classification ---- 1230 metric train_loss = 0.03970943777821958
# classification ---- 1240 metric train_loss = 0.06388314701616764
# classification ---- 1250 metric train_loss = 0.06358202900737524
# classification ---- 1260 metric train_loss = 0.04627709845080972
# classification ---- 1270 metric train_loss = 0.0608640905469656
# classification ---- 1280 metric train_loss = 0.057660711370408534
# classification ---- 1290 metric train_loss = 0.03846324936021119
# classification ---- 1300 metric train_loss = 0.11350893452763558
# classification ---- 1310 metric train_loss = 0.06718234764412045
# classification ---- 1320 metric train_loss = 0.13408407857641577
# classification ---- 1330 metric train_loss = 0.06729576103389263
# classification ---- 1340 metric train_loss = 0.08626430016011
# classification ---- 1350 metric train_loss = 0.06747142598032951
# classification ---- 1360 metric train_loss = 0.05003836061805487
# classification ---- 1370 metric train_loss = 0.04621653836220503
# classification ---- 1380 metric train_loss = 0.08402664177119731
# classification ---- 1390 metric train_loss = 0.03876755004748702
# classification ---- 1400 metric train_loss = 0.04523343346081674
# classification ---- 1410 metric train_loss = 0.06819908954203129
# classification ---- 1420 metric train_loss = 0.022135866759344935
# classification ---- 1430 metric train_loss = 0.08487126734107733
# classification ---- 1440 metric train_loss = 0.04395002173259854
# classification ---- 1450 metric train_loss = 0.020375263039022685
# classification ---- 1460 metric train_loss = 0.03852832554839551
# classification ---- 1470 metric train_loss = 0.017063288739882408
# classification ---- 1480 metric train_loss = 0.04978073742240667
# classification ---- 1490 metric train_loss = 0.12328170444816351
# classification ---- 1500 metric train_loss = 0.04593606339767575
# classification ---- 4 metric test_f1 = 0.9188984529710501
# classification ---- 1510 metric train_loss = 0.04762237817049027
# classification ---- 1520 metric train_loss = 0.04978992654941976
# classification ---- 1530 metric train_loss = 0.051392150297760966
# classification ---- 1540 metric train_loss = 0.028292144741863014
# classification ---- 1550 metric train_loss = 0.075050834659487
# classification ---- 1560 metric train_loss = 0.04337237076833844
# classification ---- 1570 metric train_loss = 0.07887053820304572
# classification ---- 1580 metric train_loss = 0.05412403387017548
# classification ---- 1590 metric train_loss = 0.062049401178956035
# classification ---- 1600 metric train_loss = 0.032738509401679036
# classification ---- 1610 metric train_loss = 0.029319975525140762
# classification ---- 1620 metric train_loss = 0.053205693466588856
# classification ---- 1630 metric train_loss = 0.06615096931345761
# classification ---- 1640 metric train_loss = 0.04830011818557978
# classification ---- 1650 metric train_loss = 0.05112647004425526
# classification ---- 1660 metric train_loss = 0.05271719610318541
# classification ---- 1670 metric train_loss = 0.05769520117901265
# classification ---- 1680 metric train_loss = 0.0615820680744946
# classification ---- 1690 metric train_loss = 0.06236157389357686
# classification ---- 1700 metric train_loss = 0.06565482541918755
# classification ---- 1710 metric train_loss = 0.05311209158971906
# classification ---- 1720 metric train_loss = 0.04876709692180157
# classification ---- 1730 metric train_loss = 0.05242916909046471
# classification ---- 1740 metric train_loss = 0.06661302000284194
# classification ---- 1750 metric train_loss = 0.029492304287850858
# classification ---- 1760 metric train_loss = 0.03820859962143004
# classification ---- 1770 metric train_loss = 0.07991713220253586
# classification ---- 1780 metric train_loss = 0.03154040216468275
# classification ---- 1790 metric train_loss = 0.07013443894684315
# classification ---- 1800 metric train_loss = 0.04121589930728078
# classification ---- 1810 metric train_loss = 0.035219823382794856
# classification ---- 1820 metric train_loss = 0.042062136111781
# classification ---- 1830 metric train_loss = 0.04692770484834909
# classification ---- 1840 metric train_loss = 0.07127551874145865
# classification ---- 1850 metric train_loss = 0.04787738285958767
# classification ---- 1860 metric train_loss = 0.03201536117121577
# classification ---- 1870 metric train_loss = 0.05172544931992888
# classification ---- 1880 metric train_loss = 0.035983720095828176
# classification ---- 1890 metric train_loss = 0.037359230848960576
# classification ---- 1900 metric train_loss = 0.02508336699102074
# classification ---- 1910 metric train_loss = 0.058663238771259785
# classification ---- 1920 metric train_loss = 0.030945462919771672
# classification ---- 1930 metric train_loss = 0.042913654097355904
# classification ---- 1940 metric train_loss = 0.033989318553358315
# classification ---- 1950 metric train_loss = 0.03401333650108427
# classification ---- 1960 metric train_loss = 0.0331708668731153
# classification ---- 1970 metric train_loss = 0.04558968381024897
# classification ---- 1980 metric train_loss = 0.061636353144422174
# classification ---- 1990 metric train_loss = 0.04513576840981841
# classification ---- 2000 metric train_loss = 0.03187346342019737
# classification ---- 5 metric test_f1 = 0.9588313135715291
# classification ---- 3 metric train_f1 = 0.9590856286622113
# classification ---- 2010 metric train_loss = 0.027692910889163612
# classification ---- 2020 metric train_loss = 0.041757080471143126
# classification ---- 2030 metric train_loss = 0.0454366696998477
# classification ---- 2040 metric train_loss = 0.032685607264284045
# classification ---- 2050 metric train_loss = 0.02428234866820276
# classification ---- 2060 metric train_loss = 0.0737997803138569
# classification ---- 2070 metric train_loss = 0.043080394994467495
# classification ---- 2080 metric train_loss = 0.04510053033009172
# classification ---- 2090 metric train_loss = 0.04999281601049006
# classification ---- 2100 metric train_loss = 0.049883618019521236
# classification ---- 2110 metric train_loss = 0.06657757014036178
# classification ---- 2120 metric train_loss = 0.030252966796979308
# classification ---- 2130 metric train_loss = 0.031201662844978273
# classification ---- 2140 metric train_loss = 0.030395849142223597
# classification ---- 2150 metric train_loss = 0.03901165216229856
# classification ---- 2160 metric train_loss = 0.039426635525887835
# classification ---- 2170 metric train_loss = 0.02432404984720051
# classification ---- 2180 metric train_loss = 0.022060139570385218
# classification ---- 2190 metric train_loss = 0.0549580761231482
# classification ---- 2200 metric train_loss = 0.04897968210279942
# classification ---- 2210 metric train_loss = 0.05204185256734491
# classification ---- 2220 metric train_loss = 0.03647587187588215
# classification ---- 2230 metric train_loss = 0.054091177857480945
# classification ---- 2240 metric train_loss = 0.04162751664407551
# classification ---- 2250 metric train_loss = 0.04099813187494874
# classification ---- 2260 metric train_loss = 0.06339155030436813
# classification ---- 2270 metric train_loss = 0.0678682429715991
# classification ---- 2280 metric train_loss = 0.01834772976581007
# classification ---- 2290 metric train_loss = 0.034631553944200276
# classification ---- 2300 metric train_loss = 0.027019690815359355
# classification ---- 2310 metric train_loss = 0.05729283043183386
# classification ---- 2320 metric train_loss = 0.023214975465089084
# classification ---- 2330 metric train_loss = 0.018561185407452285
# classification ---- 2340 metric train_loss = 0.044440725119784474
# classification ---- 2350 metric train_loss = 0.031430608872324226
# classification ---- 2360 metric train_loss = 0.05076057696714997
# classification ---- 2370 metric train_loss = 0.05540008507668972
# classification ---- 2380 metric train_loss = 0.019804783398285508
# classification ---- 2390 metric train_loss = 0.046670708968304095
# classification ---- 2400 metric train_loss = 0.040009099058806896
# classification ---- 2410 metric train_loss = 0.06020650849677622
# classification ---- 2420 metric train_loss = 0.04358867462724447
# classification ---- 2430 metric train_loss = 0.046297246823087335
# classification ---- 2440 metric train_loss = 0.0572364762891084
# classification ---- 2450 metric train_loss = 0.03885841828305274
# classification ---- 2460 metric train_loss = 0.02849251194857061
# classification ---- 2470 metric train_loss = 0.033494683215394616
# classification ---- 2480 metric train_loss = 0.03330585167277604
# classification ---- 2490 metric train_loss = 0.018712193239480257
# classification ---- 2500 metric train_loss = 0.034640482161194086
# classification ---- 6 metric test_f1 = 0.9314309873976363
# classification ---- 2510 metric train_loss = 0.04493753300048411
# classification ---- 2520 metric train_loss = 0.022549320384860037
# classification ---- 2530 metric train_loss = 0.011139697046019137
# classification ---- 2540 metric train_loss = 0.032114611659199
# classification ---- 2550 metric train_loss = 0.022027075540972874
# classification ---- 2560 metric train_loss = 0.03998645263491198
# classification ---- 2570 metric train_loss = 0.016765762493014334
# classification ---- 2580 metric train_loss = 0.03545377324335277
# classification ---- 2590 metric train_loss = 0.05799350254237652
# classification ---- 2600 metric train_loss = 0.057337669935077426
# classification ---- 2610 metric train_loss = 0.04665045402944088
# classification ---- 2620 metric train_loss = 0.05254819003166631
# classification ---- 2630 metric train_loss = 0.05873975541908294
# classification ---- 2640 metric train_loss = 0.03226503329351545
# classification ---- 2650 metric train_loss = 0.05072323605418205
# classification ---- 2660 metric train_loss = 0.04506845921278
# classification ---- 2670 metric train_loss = 0.04294296281877905
# classification ---- 2680 metric train_loss = 0.030130489356815816
# classification ---- 2690 metric train_loss = 0.06062636859714985
# classification ---- 2700 metric train_loss = 0.03896325174719095
# classification ---- 2710 metric train_loss = 0.028024874441325665
# classification ---- 2720 metric train_loss = 0.0790577471256256
# classification ---- 2730 metric train_loss = 0.06804710566066205
# classification ---- 2740 metric train_loss = 0.026552744070068003
# classification ---- 2750 metric train_loss = 0.03556860859971493
# classification ---- 2760 metric train_loss = 0.04307879160623997
# classification ---- 2770 metric train_loss = 0.03466870579868555
# classification ---- 2780 metric train_loss = 0.04609637586399913
# classification ---- 2790 metric train_loss = 0.04140527532435954
# classification ---- 2800 metric train_loss = 0.025598255312070252
# classification ---- 2810 metric train_loss = 0.0436480587348342
# classification ---- 2820 metric train_loss = 0.03913251345511526
# classification ---- 2830 metric train_loss = 0.029808267811313273
# classification ---- 2840 metric train_loss = 0.025780071347253398
# classification ---- 2850 metric train_loss = 0.037946066539734605
# classification ---- 2860 metric train_loss = 0.01769531045574695
# classification ---- 2870 metric train_loss = 0.032173264981247486
# classification ---- 2880 metric train_loss = 0.03549365431535989
# classification ---- 2890 metric train_loss = 0.03760351766832173
# classification ---- 2900 metric train_loss = 0.039668810949660835
# classification ---- 2910 metric train_loss = 0.045722569432109596
# classification ---- 2920 metric train_loss = 0.03740237667225301
# classification ---- 2930 metric train_loss = 0.02971957642585039
# classification ---- 2940 metric train_loss = 0.03078004173003137
# classification ---- 2950 metric train_loss = 0.022786219231784345
# classification ---- 2960 metric train_loss = 0.040330608282238244
# classification ---- 2970 metric train_loss = 0.03266605050303042
# classification ---- 2980 metric train_loss = 0.056150157912634314
# classification ---- 2990 metric train_loss = 0.018474862980656325
# classification ---- 3000 metric train_loss = 0.04877992514520883
# classification ---- 7 metric test_f1 = 0.9284700340869554
# classification ---- 4 metric train_f1 = 0.9595531415590239
# classification ---- 3010 metric train_loss = 0.03402281973976642
# classification ---- 3020 metric train_loss = 0.027442886936478318
# classification ---- 3030 metric train_loss = 0.028636132937390358
# classification ---- 3040 metric train_loss = 0.035473510064184664
# classification ---- 3050 metric train_loss = 0.04285452882759273
# classification ---- 3060 metric train_loss = 0.01611946247285232
# classification ---- 3070 metric train_loss = 0.04581750952638686
# classification ---- 3080 metric train_loss = 0.014698314806446433
# classification ---- 3090 metric train_loss = 0.027961743297055364
# classification ---- 3100 metric train_loss = 0.0200779952458106
# classification ---- 3110 metric train_loss = 0.035255899396725
# classification ---- 3120 metric train_loss = 0.06441951086744666
# classification ---- 3130 metric train_loss = 0.07404084070585668
# classification ---- 3140 metric train_loss = 0.05577741926535964
# classification ---- 3150 metric train_loss = 0.026213376317173243
# classification ---- 3160 metric train_loss = 0.04753845082595944
# classification ---- 3170 metric train_loss = 0.04969065934419632
# classification ---- 3180 metric train_loss = 0.024215654004365206
# classification ---- 3190 metric train_loss = 0.051707106688991186
# classification ---- 3200 metric train_loss = 0.04117766502313316
# classification ---- 3210 metric train_loss = 0.035006589931435884
# classification ---- 3220 metric train_loss = 0.05713576567359269
# classification ---- 3230 metric train_loss = 0.03937567193061113
# classification ---- 3240 metric train_loss = 0.027860550326295197
# classification ---- 3250 metric train_loss = 0.03312398921698332
# classification ---- 3260 metric train_loss = 0.03230181547114626
# classification ---- 3270 metric train_loss = 0.04722312001977116
# classification ---- 3280 metric train_loss = 0.02990294584305957
# classification ---- 3290 metric train_loss = 0.01694728690199554
# classification ---- 3300 metric train_loss = 0.029102872754447163
# classification ---- 3310 metric train_loss = 0.03253039191477001
# classification ---- 3320 metric train_loss = 0.03303661127574742
# classification ---- 3330 metric train_loss = 0.041990464366972444
# classification ---- 3340 metric train_loss = 0.02534710642648861
# classification ---- 3350 metric train_loss = 0.030136861896608025
# classification ---- 3360 metric train_loss = 0.03415602121967822
# classification ---- 3370 metric train_loss = 0.02349630908574909
# classification ---- 3380 metric train_loss = 0.014444275386631488
# classification ---- 3390 metric train_loss = 0.0238262556027621
# classification ---- 3400 metric train_loss = 0.06158847915939987
# classification ---- 3410 metric train_loss = 0.0348519180668518
# classification ---- 3420 metric train_loss = 0.039089373964816335
# classification ---- 3430 metric train_loss = 0.035412160027772185
# classification ---- 3440 metric train_loss = 0.04928114956710487
# classification ---- 3450 metric train_loss = 0.04574849952477962
# classification ---- 3460 metric train_loss = 0.027769317757338284
# classification ---- 3470 metric train_loss = 0.04005600998643786
# classification ---- 3480 metric train_loss = 0.051225216453894974
# classification ---- 3490 metric train_loss = 0.028535174019634724
# classification ---- 3500 metric train_loss = 0.020593551313504578
# classification ---- 8 metric test_f1 = 0.9586585392139516
# classification ---- 3510 metric train_loss = 0.03415184284094721
# classification ---- 3520 metric train_loss = 0.03906018785201013
# classification ---- 3530 metric train_loss = 0.03843643283471465
# classification ---- 3540 metric train_loss = 0.03698637324851006
# classification ---- 3550 metric train_loss = 0.037497878260910514
# classification ---- 3560 metric train_loss = 0.041424766276031734
# classification ---- 3570 metric train_loss = 0.036185070569626984
# classification ---- 3580 metric train_loss = 0.04867019506637007
# classification ---- 3590 metric train_loss = 0.026578051201067866
# classification ---- 3600 metric train_loss = 0.01671203235164285
# classification ---- 3610 metric train_loss = 0.028464389499276876
# classification ---- 3620 metric train_loss = 0.06123906280845404
# classification ---- 3630 metric train_loss = 0.020203712745569646
# classification ---- 3640 metric train_loss = 0.03716209658887237
# classification ---- 3650 metric train_loss = 0.03140906472690404
# classification ---- 3660 metric train_loss = 0.03465853626839817
# classification ---- 3670 metric train_loss = 0.01925904555246234
# classification ---- 3680 metric train_loss = 0.03768560115713626
# classification ---- 3690 metric train_loss = 0.02987108309753239
# classification ---- 3700 metric train_loss = 0.03501887591555715
# classification ---- 3710 metric train_loss = 0.013566547748632729
# classification ---- 3720 metric train_loss = 0.015905582159757615
# classification ---- 3730 metric train_loss = 0.019818291068077087
# classification ---- 3740 metric train_loss = 0.02646204608026892
# classification ---- 3750 metric train_loss = 0.04300232331734151
# classification ---- 3760 metric train_loss = 0.033124207984656096
# classification ---- 3770 metric train_loss = 0.021538279484957457
# classification ---- 3780 metric train_loss = 0.018234623107127847
# classification ---- 3790 metric train_loss = 0.03589830247219652
# classification ---- 3800 metric train_loss = 0.02936745178885758
# classification ---- 3810 metric train_loss = 0.028262245398946107
# classification ---- 3820 metric train_loss = 0.03846670312341303
# classification ---- 3830 metric train_loss = 0.016330913221463562
# classification ---- 3840 metric train_loss = 0.011664964695228264
# classification ---- 3850 metric train_loss = 0.03925953470170498
# classification ---- 3860 metric train_loss = 0.0496657173614949
# classification ---- 3870 metric train_loss = 0.027936907671391963
# classification ---- 3880 metric train_loss = 0.02590267261257395
# classification ---- 3890 metric train_loss = 0.03041192142991349
# classification ---- 3900 metric train_loss = 0.02353061831090599
# classification ---- 3910 metric train_loss = 0.01983186915749684
# classification ---- 3920 metric train_loss = 0.028622053400613367
# classification ---- 3930 metric train_loss = 0.02466562296031043
# classification ---- 3940 metric train_loss = 0.023937393247615547
# classification ---- 3950 metric train_loss = 0.03343576994957402
# classification ---- 3960 metric train_loss = 0.04683484339620918
# classification ---- 3970 metric train_loss = 0.020723253255710006
# classification ---- 3980 metric train_loss = 0.05117548177950084
# classification ---- 3990 metric train_loss = 0.05334347728639841
# classification ---- 4000 metric train_loss = 0.01643378067528829
# classification ---- 9 metric test_f1 = 0.9596720087142407
# classification ---- 5 metric train_f1 = 0.9619454828859006
# classification ---- 4010 metric train_loss = 0.034307477972470225
# classification ---- 4020 metric train_loss = 0.02826162988785654
# classification ---- 4030 metric train_loss = 0.025030600652098656
# classification ---- 4040 metric train_loss = 0.02237349657807499
# classification ---- 4050 metric train_loss = 0.039224409079179165
# classification ---- 4060 metric train_loss = 0.014504399138968439
# classification ---- 4070 metric train_loss = 0.02131287781521678
# classification ---- 4080 metric train_loss = 0.023727039434015752
# classification ---- 4090 metric train_loss = 0.040173179609701036
# classification ---- 4100 metric train_loss = 0.03849008941324428
# classification ---- 4110 metric train_loss = 0.03646645885892212
# classification ---- 4120 metric train_loss = 0.031927898991853
# classification ---- 4130 metric train_loss = 0.06313307119999081
# classification ---- 4140 metric train_loss = 0.02350054255221039
# classification ---- 4150 metric train_loss = 0.028165054274722934
# classification ---- 4160 metric train_loss = 0.015872265864163636
# classification ---- 4170 metric train_loss = 0.022102342173457145
# classification ---- 4180 metric train_loss = 0.04503649357939139
# classification ---- 4190 metric train_loss = 0.052612744405632836
# classification ---- 4200 metric train_loss = 0.07369626611471176
# classification ---- 4210 metric train_loss = 0.03380786605412141
# classification ---- 4220 metric train_loss = 0.03500307914800942
# classification ---- 4230 metric train_loss = 0.018484202423132957
# classification ---- 4240 metric train_loss = 0.02743790587410331
# classification ---- 4250 metric train_loss = 0.0160652088932693
# classification ---- 4260 metric train_loss = 0.020727679971605538
# classification ---- 4270 metric train_loss = 0.03487980666104704
# classification ---- 4280 metric train_loss = 0.028352578799240292
# classification ---- 4290 metric train_loss = 0.02296307049691677
# classification ---- 4300 metric train_loss = 0.020261505199596287
# classification ---- 4310 metric train_loss = 0.04791866117157042
# classification ---- 4320 metric train_loss = 0.03796002600574866
# classification ---- 4330 metric train_loss = 0.04010136378929019
# classification ---- 4340 metric train_loss = 0.04543836039956659
# classification ---- 4350 metric train_loss = 0.02068342708516866
# classification ---- 4360 metric train_loss = 0.020275951339863242
# classification ---- 4370 metric train_loss = 0.03994266070658341
# classification ---- 4380 metric train_loss = 0.04317915276624262
# classification ---- 4390 metric train_loss = 0.028054491966031492
# classification ---- 4400 metric train_loss = 0.03296043649315834
# classification ---- 4410 metric train_loss = 0.03908722721971571
# classification ---- 4420 metric train_loss = 0.04144943859428167
# classification ---- 4430 metric train_loss = 0.02239114036783576
# classification ---- 4440 metric train_loss = 0.015353432530537248
# classification ---- 4450 metric train_loss = 0.0332379158353433
# classification ---- 4460 metric train_loss = 0.015287561132572592
# classification ---- 4470 metric train_loss = 0.031869954778812826
# classification ---- 4480 metric train_loss = 0.023523864173330366
# classification ---- 4490 metric train_loss = 0.02134063297417015
# classification ---- 4500 metric train_loss = 0.025419194903224706
# classification ---- 10 metric test_f1 = 0.913696616855916
# classification ---- 4510 metric train_loss = 0.020503885531798004
# classification ---- 4520 metric train_loss = 0.021951458195690065
# classification ---- 4530 metric train_loss = 0.015826069540344177
# classification ---- 4540 metric train_loss = 0.01693181407172233
# classification ---- 4550 metric train_loss = 0.033610108331777154
# classification ---- 4560 metric train_loss = 0.030960506340488792
# classification ---- 4570 metric train_loss = 0.026710341614671052
# classification ---- 4580 metric train_loss = 0.017167950922157615
# classification ---- 4590 metric train_loss = 0.02704208984505385
# classification ---- 4600 metric train_loss = 0.030971515015698968
# classification ---- 4610 metric train_loss = 0.022517393948510288
# classification ---- 4620 metric train_loss = 0.02223032838664949
# classification ---- 4630 metric train_loss = 0.04102917485870421
# classification ---- 4640 metric train_loss = 0.01319284772616811
# classification ---- 4650 metric train_loss = 0.03271805520635098
# classification ---- 4660 metric train_loss = 0.037612365745007995
# classification ---- 4670 metric train_loss = 0.01033986583352089
# classification ---- 4680 metric train_loss = 0.019791643088683485
# classification ---- 4690 metric train_loss = 0.037525232112966475
# classification ---- 4700 metric train_loss = 0.008091646165121346
# classification ---- 4710 metric train_loss = 0.049241431150585414
# classification ---- 4720 metric train_loss = 0.02581423781812191
# classification ---- 4730 metric train_loss = 0.015775737550575285
# classification ---- 4740 metric train_loss = 0.02960869639646262
# classification ---- 4750 metric train_loss = 0.030479848152026534
# classification ---- 4760 metric train_loss = 0.021682437881827353
# classification ---- 4770 metric train_loss = 0.03815204333513975
# classification ---- 4780 metric train_loss = 0.024430090165697037
# classification ---- 4790 metric train_loss = 0.020407210756093263
# classification ---- 4800 metric train_loss = 0.0311070671537891
# classification ---- 4810 metric train_loss = 0.02463499514851719
# classification ---- 4820 metric train_loss = 0.03820082842721604
# classification ---- 4830 metric train_loss = 0.025823388108983637
# classification ---- 4840 metric train_loss = 0.031038580217864365
# classification ---- 4850 metric train_loss = 0.019931289204396307
# classification ---- 4860 metric train_loss = 0.011335107625927775
# classification ---- 4870 metric train_loss = 0.027676213532686234
# classification ---- 4880 metric train_loss = 0.031909113237634304
# classification ---- 4890 metric train_loss = 0.02087483904324472
# classification ---- 4900 metric train_loss = 0.012350726453587414
# classification ---- 4910 metric train_loss = 0.03856801226502284
# classification ---- 4920 metric train_loss = 0.023264983436092734
# classification ---- 4930 metric train_loss = 0.03586002625524998
# classification ---- 4940 metric train_loss = 0.025973908440209924
# classification ---- 4950 metric train_loss = 0.10005668557714671
# classification ---- 4960 metric train_loss = 0.0546773046371527
# classification ---- 4970 metric train_loss = 0.05502666928805411
# classification ---- 4980 metric train_loss = 0.02669117017649114
# classification ---- 4990 metric train_loss = 0.01146929725073278
# classification ---- 5000 metric train_loss = 0.015039834333583713
# classification ---- 11 metric test_f1 = 0.9249566357250333
# classification ---- 6 metric train_f1 = 0.9733053395778346
# classification ---- 5010 metric train_loss = 0.021096956240944563
# classification ---- 5020 metric train_loss = 0.033278802619315685
# classification ---- 5030 metric train_loss = 0.04387270323932171
# classification ---- 5040 metric train_loss = 0.024869462451897563
# classification ---- 5050 metric train_loss = 0.01833146932767704
# classification ---- 5060 metric train_loss = 0.006625740381423384
# classification ---- 5070 metric train_loss = 0.045261014776770025
# classification ---- 5080 metric train_loss = 0.04101638086140156
# classification ---- 5090 metric train_loss = 0.0424753915052861
# classification ---- 5100 metric train_loss = 0.033407111186534166
# classification ---- 5110 metric train_loss = 0.023785222414880992
# classification ---- 5120 metric train_loss = 0.01667973891599104
# classification ---- 5130 metric train_loss = 0.01874071339843795
# classification ---- 5140 metric train_loss = 0.032939457276370376
# classification ---- 5150 metric train_loss = 0.02828384037129581
# classification ---- 5160 metric train_loss = 0.027372153103351594
# classification ---- 5170 metric train_loss = 0.0158425813075155
# classification ---- 5180 metric train_loss = 0.024910114938393235
# classification ---- 5190 metric train_loss = 0.03289368492551148
# classification ---- 5200 metric train_loss = 0.03447730655316263
# classification ---- 5210 metric train_loss = 0.013775656465440989
# classification ---- 5220 metric train_loss = 0.028142225532792508
# classification ---- 5230 metric train_loss = 0.019565552577842028
# classification ---- 5240 metric train_loss = 0.008893584564793855
# classification ---- 5250 metric train_loss = 0.024781548068858683
# classification ---- 5260 metric train_loss = 0.01695184928830713
# classification ---- 5270 metric train_loss = 0.01681406491261441
# classification ---- 5280 metric train_loss = 0.05085108160274103
# classification ---- 5290 metric train_loss = 0.014096492005046457
# classification ---- 5300 metric train_loss = 0.015621236711740493
# classification ---- 5310 metric train_loss = 0.011820519622415305
# classification ---- 5320 metric train_loss = 0.01644939222605899
# classification ---- 5330 metric train_loss = 0.03477523089386523
# classification ---- 5340 metric train_loss = 0.018139557784888894
# classification ---- 5350 metric train_loss = 0.027872522972756997
# classification ---- 5360 metric train_loss = 0.03378768675029278
# classification ---- 5370 metric train_loss = 0.025589834712445737
# classification ---- 5380 metric train_loss = 0.03202102630166337
# classification ---- 5390 metric train_loss = 0.02895426293835044
# classification ---- 5400 metric train_loss = 0.030449385428801178
# classification ---- 5410 metric train_loss = 0.023277360084466635
# classification ---- 5420 metric train_loss = 0.027850993920583277
# classification ---- 5430 metric train_loss = 0.017373135924572125
# classification ---- 5440 metric train_loss = 0.02887790839886293
# classification ---- 5450 metric train_loss = 0.011184196267277003
# classification ---- 5460 metric train_loss = 0.015022537048207597
# classification ---- 5470 metric train_loss = 0.023398537607863545
# classification ---- 5480 metric train_loss = 0.014664667705073953
# classification ---- 5490 metric train_loss = 0.0064254448807332665
# classification ---- 5500 metric train_loss = 0.03156397085404024
# classification ---- 12 metric test_f1 = 0.9496153650314028
# classification ---- 5510 metric train_loss = 0.013296420918777585
# classification ---- 5520 metric train_loss = 0.010971962078474461
# classification ---- 5530 metric train_loss = 0.057641775102820245
# classification ---- 5540 metric train_loss = 0.015772147523239254
# classification ---- 5550 metric train_loss = 0.027321011712774634
# classification ---- 5560 metric train_loss = 0.017832257627742366
# classification ---- 5570 metric train_loss = 0.012267337692901493
# classification ---- 5580 metric train_loss = 0.019528291770257056
# classification ---- 5590 metric train_loss = 0.021492741513065995
# classification ---- 5600 metric train_loss = 0.055317981156986204
# classification ---- 5610 metric train_loss = 0.03917757410090417
# classification ---- 5620 metric train_loss = 0.034081813390366734
# classification ---- 5630 metric train_loss = 0.03588991501601413
# classification ---- 5640 metric train_loss = 0.014690724504180252
# classification ---- 5650 metric train_loss = 0.02579661721829325
# classification ---- 5660 metric train_loss = 0.009332404599990695
# classification ---- 5670 metric train_loss = 0.027660702588036656
# classification ---- 5680 metric train_loss = 0.03444323016447015
# classification ---- 5690 metric train_loss = 0.02463476106058806
# classification ---- 5700 metric train_loss = 0.02525445430073887
# classification ---- 5710 metric train_loss = 0.011464790673926473
# classification ---- 5720 metric train_loss = 0.02008603358408436
# classification ---- 5730 metric train_loss = 0.039957144332583995
# classification ---- 5740 metric train_loss = 0.0433437624713406
# classification ---- 5750 metric train_loss = 0.029314798256382345
# classification ---- 5760 metric train_loss = 0.020486636413261296
# classification ---- 5770 metric train_loss = 0.032863259152509275
# classification ---- 5780 metric train_loss = 0.020548241399228572
# classification ---- 5790 metric train_loss = 0.026068594196112828
# classification ---- 5800 metric train_loss = 0.027252697106450795
# classification ---- 5810 metric train_loss = 0.024331471510231496
# classification ---- 5820 metric train_loss = 0.012385780026670545
# classification ---- 5830 metric train_loss = 0.0184403293475043
# classification ---- 5840 metric train_loss = 0.011804382526315748
# classification ---- 5850 metric train_loss = 0.024844477802980693
# classification ---- 5860 metric train_loss = 0.024723368498962374
# classification ---- 5870 metric train_loss = 0.028105715732090177
# classification ---- 5880 metric train_loss = 0.03535183686763048
# classification ---- 5890 metric train_loss = 0.013453560741618275
# classification ---- 5900 metric train_loss = 0.0461537029594183
# classification ---- 5910 metric train_loss = 0.026637663249857724
# classification ---- 5920 metric train_loss = 0.017966110119596125
# classification ---- 5930 metric train_loss = 0.020472979702753948
# classification ---- 5940 metric train_loss = 0.014765775669366122
# classification ---- 5950 metric train_loss = 0.01949890502728522
# classification ---- 5960 metric train_loss = 0.015800543990917505
# classification ---- 5970 metric train_loss = 0.015481630072463304
# classification ---- 5980 metric train_loss = 0.02782766046002507
# classification ---- 5990 metric train_loss = 0.008059554058127106
# classification ---- 6000 metric train_loss = 0.0468055096513126
# classification ---- 13 metric test_f1 = 0.923302655377387
# classification ---- 7 metric train_f1 = 0.9661510905149687
# classification ---- 6010 metric train_loss = 0.026213088346412405
# classification ---- 6020 metric train_loss = 0.005992107640486211
# classification ---- 6030 metric train_loss = 0.02504197755479254
# classification ---- 6040 metric train_loss = 0.007932465098565444
# classification ---- 6050 metric train_loss = 0.010792987933382393
# classification ---- 6060 metric train_loss = 0.02183374878950417
# classification ---- 6070 metric train_loss = 0.016818911535665393
# classification ---- 6080 metric train_loss = 0.03985589719377458
# classification ---- 6090 metric train_loss = 0.009793059277581052
# classification ---- 6100 metric train_loss = 0.024490820441860704
# classification ---- 6110 metric train_loss = 0.016481598987593316
# classification ---- 6120 metric train_loss = 0.03176935627125203
# classification ---- 6130 metric train_loss = 0.02912624659948051
# classification ---- 6140 metric train_loss = 0.014022001810371876
# classification ---- 6150 metric train_loss = 0.044081026967614886
# classification ---- 6160 metric train_loss = 0.044229585747234526
# classification ---- 6170 metric train_loss = 0.020554088638164103
# classification ---- 6180 metric train_loss = 0.045882540300954136
# classification ---- 6190 metric train_loss = 0.008451499626971781
# classification ---- 6200 metric train_loss = 0.01778480738867074
# classification ---- 6210 metric train_loss = 0.027613307861611248
# classification ---- 6220 metric train_loss = 0.02265497758053243
# classification ---- 6230 metric train_loss = 0.02367956778034568
# classification ---- 6240 metric train_loss = 0.021744639461394398
# classification ---- 6250 metric train_loss = 0.016987669421359895
# classification ---- 6260 metric train_loss = 0.0228963777073659
# classification ---- 6270 metric train_loss = 0.03320047934539616
# classification ---- 6280 metric train_loss = 0.01728920217137784
# classification ---- 6290 metric train_loss = 0.015910075686406344
# classification ---- 6300 metric train_loss = 0.01886727918172255
# classification ---- 6310 metric train_loss = 0.01775703819002956
# classification ---- 6320 metric train_loss = 0.016685306269209832
# classification ---- 6330 metric train_loss = 0.018544930359348656
# classification ---- 6340 metric train_loss = 0.016924323991406708
# classification ---- 6350 metric train_loss = 0.008024846907937899
# classification ---- 6360 metric train_loss = 0.0251339715992799
# classification ---- 6370 metric train_loss = 0.027982452523428947
# classification ---- 6380 metric train_loss = 0.030534844333305954
# classification ---- 6390 metric train_loss = 0.020381748711224647
# classification ---- 6400 metric train_loss = 0.014126301603391766
# classification ---- 6410 metric train_loss = 0.028357151511590926
# classification ---- 6420 metric train_loss = 0.014359946851618588
# classification ---- 6430 metric train_loss = 0.06687121933791787
# classification ---- 6440 metric train_loss = 0.039463622076436874
# classification ---- 6450 metric train_loss = 0.02378082014620304
# classification ---- 6460 metric train_loss = 0.03838792415335775
# classification ---- 6470 metric train_loss = 0.03585261264815927
# classification ---- 6480 metric train_loss = 0.023681178980041295
# classification ---- 6490 metric train_loss = 0.034697407856583595
# classification ---- 6500 metric train_loss = 0.01477038327138871
# classification ---- 14 metric test_f1 = 0.9379758143553736
# classification ---- 6510 metric train_loss = 0.011597605736460537
# classification ---- 6520 metric train_loss = 0.042689097858965394
# classification ---- 6530 metric train_loss = 0.01852809959091246
# classification ---- 6540 metric train_loss = 0.009548810782143846
# classification ---- 6550 metric train_loss = 0.020343113830313085
# classification ---- 6560 metric train_loss = 0.043923405720852314
# classification ---- 6570 metric train_loss = 0.03965445156209171
# classification ---- 6580 metric train_loss = 0.020904444134794177
# classification ---- 6590 metric train_loss = 0.019100555777549745
# classification ---- 6600 metric train_loss = 0.02447979326825589
# classification ---- 6610 metric train_loss = 0.029107921954710035
# classification ---- 6620 metric train_loss = 0.032902493118308486
# classification ---- 6630 metric train_loss = 0.0279130965936929
# classification ---- 6640 metric train_loss = 0.03771023547742516
# classification ---- 6650 metric train_loss = 0.017121195211075246
# classification ---- 6660 metric train_loss = 0.026320660230703653
# classification ---- 6670 metric train_loss = 0.02151949137914926
# classification ---- 6680 metric train_loss = 0.014160235424060374
# classification ---- 6690 metric train_loss = 0.00902329472010024
# classification ---- 6700 metric train_loss = 0.024911352063645607
# classification ---- 6710 metric train_loss = 0.024005351145751773
# classification ---- 6720 metric train_loss = 0.030038096499629317
# classification ---- 6730 metric train_loss = 0.02517869065050036
# classification ---- 6740 metric train_loss = 0.021953202644363047
# classification ---- 6750 metric train_loss = 0.027683402586262673
# classification ---- 6760 metric train_loss = 0.03351016468368471
# classification ---- 6770 metric train_loss = 0.018698949686950073
# classification ---- 6780 metric train_loss = 0.03635889985598624
# classification ---- 6790 metric train_loss = 0.01950584186706692
# classification ---- 6800 metric train_loss = 0.016765024210326374
# classification ---- 6810 metric train_loss = 0.02524092737585306
# classification ---- 6820 metric train_loss = 0.01856130458181724
# classification ---- 6830 metric train_loss = 0.020856874785386025
# classification ---- 6840 metric train_loss = 0.016788857767824083
# classification ---- 6850 metric train_loss = 0.014508883957751096
# classification ---- 6860 metric train_loss = 0.01662641192378942
# classification ---- 6870 metric train_loss = 0.00804346043150872
# classification ---- 6880 metric train_loss = 0.03658267178107053
# classification ---- 6890 metric train_loss = 0.010107277985662222
# classification ---- 6900 metric train_loss = 0.016114336834289134
# classification ---- 6910 metric train_loss = 0.02020607953891158
# classification ---- 6920 metric train_loss = 0.0100501257868018
# classification ---- 6930 metric train_loss = 0.019205811031861232
# classification ---- 6940 metric train_loss = 0.015706641878932715
# classification ---- 6950 metric train_loss = 0.024933767499169333
# classification ---- 6960 metric train_loss = 0.018864433921407908
# classification ---- 6970 metric train_loss = 0.015144099874305539
# classification ---- 6980 metric train_loss = 0.012475675309542567
# classification ---- 6990 metric train_loss = 0.013947354795527644
# classification ---- 7000 metric train_loss = 0.03877427213592455
# classification ---- 15 metric test_f1 = 0.9589628329549387
# classification ---- 8 metric train_f1 = 0.9676883154993832
# classification ---- 7010 metric train_loss = 0.04889185247011483
# classification ---- 7020 metric train_loss = 0.02072589977760799
# classification ---- 7030 metric train_loss = 0.03224454135634005
# classification ---- 7040 metric train_loss = 0.013739679782884196
# classification ---- 7050 metric train_loss = 0.038710854342207314
# classification ---- 7060 metric train_loss = 0.021711435326142236
# classification ---- 7070 metric train_loss = 0.019458081806078553
# classification ---- 7080 metric train_loss = 0.024138661520555615
# classification ---- 7090 metric train_loss = 0.0327162328758277
# classification ---- 7100 metric train_loss = 0.017305341234896333
# classification ---- 7110 metric train_loss = 0.018322845583315938
# classification ---- 7120 metric train_loss = 0.026110532763414084
# classification ---- 7130 metric train_loss = 0.020799312554299832
# classification ---- 7140 metric train_loss = 0.013144259969703854
# classification ---- 7150 metric train_loss = 0.015250868874136358
# classification ---- 7160 metric train_loss = 0.02719543600687757
# ...
# classification ---- 13050 metric train_loss = 0.011955771187786013
# classification ---- 13060 metric train_loss = 0.02698668739758432
# classification ---- 13070 metric train_loss = 0.04105572607368231
# classification ---- 13080 metric train_loss = 0.0176511749625206
# classification ---- 13090 metric train_loss = 0.02242556481505744
# classification ---- 13100 metric train_loss = 0.020334396499674768
# classification ---- 13110 metric train_loss = 0.005474341759691015
# classification ---- 13120 metric train_loss = 0.00806695243518334
# classification ---- 13130 metric train_loss = 0.015157345042098314
# classification ---- 13140 metric train_loss = 0.011059684026986361
# classification ---- 13150 metric train_loss = 0.009404124863795004
# classification ---- 13160 metric train_loss = 0.021642126189544798
# classification ---- 13170 metric train_loss = 0.014760725048836321
# classification ---- 13180 metric train_loss = 0.012155659357085824
# classification ---- 13190 metric train_loss = 0.01250068397494033
# classification ---- 13200 metric train_loss = 0.01838182101782877
# classification ---- 13210 metric train_loss = 0.011576686517219058
# classification ---- 13220 metric train_loss = 0.012996216613100842
# classification ---- 13230 metric train_loss = 0.019782750561716966
# classification ---- 13240 metric train_loss = 0.028609239705838264
# classification ---- 13250 metric train_loss = 0.006022119079716504
# classification ---- 13260 metric train_loss = 0.01001920736161992
# classification ---- 13270 metric train_loss = 0.010752607195172459
# classification ---- 13280 metric train_loss = 0.008557085506618023
# classification ---- 13290 metric train_loss = 0.02583263881970197
# classification ---- 13300 metric train_loss = 0.01691346784355119
# classification ---- 13310 metric train_loss = 0.00885472382651642
# classification ---- 13320 metric train_loss = 0.003962105244863778
# classification ---- 13330 metric train_loss = 0.03434385088039562
# classification ---- 13340 metric train_loss = 0.02134877674980089
# classification ---- 13350 metric train_loss = 0.016664024454075842
# classification ---- 13360 metric train_loss = 0.01760643096640706
# classification ---- 13370 metric train_loss = 0.008565216109855101
# classification ---- 13380 metric train_loss = 0.01043136754014995
# classification ---- 13390 metric train_loss = 0.024180068186251447
# classification ---- 13400 metric train_loss = 0.01023140331672039
# classification ---- 13410 metric train_loss = 0.015477492188801989
# classification ---- 13420 metric train_loss = 0.007436789316125214
# classification ---- 13430 metric train_loss = 0.008382352351327426
# classification ---- 13440 metric train_loss = 0.012213808426167816
# classification ---- 13450 metric train_loss = 0.006600837275618688
# classification ---- 13460 metric train_loss = 0.028135226760059594
# classification ---- 13470 metric train_loss = 0.011108511680504307
# classification ---- 13480 metric train_loss = 0.005940582601760979
# classification ---- 13490 metric train_loss = 0.02023349028895609
# classification ---- 13500 metric train_loss = 0.02664230249938555
# classification ---- 28 metric test_f1 = 0.9229643831144059
# classification ---- 13510 metric train_loss = 0.01937708866316825
# classification ---- 13520 metric train_loss = 0.02000948884524405
# classification ---- 13530 metric train_loss = 0.007240985107637243
# classification ---- 13540 metric train_loss = 0.013800310506485402
# classification ---- 13550 metric train_loss = 0.019087712658802047
# classification ---- 13560 metric train_loss = 0.010221666772849858
# classification ---- 13570 metric train_loss = 0.01509289859677665
# classification ---- 13580 metric train_loss = 0.031220558169297873
# classification ---- 13590 metric train_loss = 0.028274657553993165
# classification ---- 13600 metric train_loss = 0.02444224782520905
# classification ---- 13610 metric train_loss = 0.024593580910004676
# classification ---- 13620 metric train_loss = 0.017343710886780172
# classification ---- 13630 metric train_loss = 0.011794592649675906
# classification ---- 13640 metric train_loss = 0.021373814856633543
# classification ---- 13650 metric train_loss = 0.04138712270651013
# classification ---- 13660 metric train_loss = 0.030194603744894265
# classification ---- 13670 metric train_loss = 0.024773285089759157
# classification ---- 13680 metric train_loss = 0.029427717521321027
# classification ---- 13690 metric train_loss = 0.024999743269290775
# classification ---- 13700 metric train_loss = 0.02324911251780577
# classification ---- 13710 metric train_loss = 0.027810512227006257
# classification ---- 13720 metric train_loss = 0.015466665284475312
# classification ---- 13730 metric train_loss = 0.021935196220874788
# classification ---- 13740 metric train_loss = 0.01316717864247039
# classification ---- 13750 metric train_loss = 0.015346390253398567
# classification ---- 13760 metric train_loss = 0.008749928956967778
# classification ---- 13770 metric train_loss = 0.02531231862376444
# classification ---- 13780 metric train_loss = 0.02186072225449607
# classification ---- 13790 metric train_loss = 0.009143492800649255
# classification ---- 13800 metric train_loss = 0.0070281443418934945
# classification ---- 13810 metric train_loss = 0.015734235872514546
# classification ---- 13820 metric train_loss = 0.009396196465240791
# classification ---- 13830 metric train_loss = 0.01512006722332444
# classification ---- 13840 metric train_loss = 0.025148754473775625
# classification ---- 13850 metric train_loss = 0.019491313927574083
# classification ---- 13860 metric train_loss = 0.005178614601027221
# classification ---- 13870 metric train_loss = 0.008241081860614941
# classification ---- 13880 metric train_loss = 0.007131941089755856
# classification ---- 13890 metric train_loss = 0.018773867504205555
# classification ---- 13900 metric train_loss = 0.012031941964232828
# classification ---- 13910 metric train_loss = 0.01596470905933529
# classification ---- 13920 metric train_loss = 0.02253795340657234
# classification ---- 13930 metric train_loss = 0.021809197004768067
# classification ---- 13940 metric train_loss = 0.02451761403353885
# classification ---- 13950 metric train_loss = 0.013533529185224324
# classification ---- 13960 metric train_loss = 0.0056315716414246705
# classification ---- 13970 metric train_loss = 0.004063548010890372
# classification ---- 13980 metric train_loss = 0.01797628350905143
# classification ---- 13990 metric train_loss = 0.006076483246579301
# classification ---- 14000 metric train_loss = 0.013267437007743865
# classification ---- 29 metric test_f1 = 0.9400685115118109
# classification ---- 15 metric train_f1 = 0.9777898578168425
# classification ---- 14010 metric train_loss = 0.009487273992272094
# classification ---- 14020 metric train_loss = 0.009388870920520275
# classification ---- 14030 metric train_loss = 0.007318619523721282
# classification ---- 14040 metric train_loss = 0.013750563026405871
# classification ---- 14050 metric train_loss = 0.003747532649140339
# classification ---- 14060 metric train_loss = 0.007549476435087854
# classification ---- 14070 metric train_loss = 0.012738961419381667
# classification ---- 14080 metric train_loss = 0.014050948311341927
# classification ---- 14090 metric train_loss = 0.014412703714333475
# classification ---- 14100 metric train_loss = 0.02260566885379376
# classification ---- 14110 metric train_loss = 0.016546508169267327
# classification ---- 14120 metric train_loss = 0.016400232200976462
# classification ---- 14130 metric train_loss = 0.009862233197782188
# classification ---- 14140 metric train_loss = 0.020388520054984836
# classification ---- 14150 metric train_loss = 0.015729736642242642
# classification ---- 14160 metric train_loss = 0.01634686305769719
# classification ---- 14170 metric train_loss = 0.008538951829541475
# classification ---- 14180 metric train_loss = 0.008203099411912263
# classification ---- 14190 metric train_loss = 0.015625919576268642
# classification ---- 14200 metric train_loss = 0.013348468282492832
# classification ---- 14210 metric train_loss = 0.017141318472567946
# classification ---- 14220 metric train_loss = 0.03158183835912496
# classification ---- 14230 metric train_loss = 0.013768352684564888
# classification ---- 14240 metric train_loss = 0.02403388130478561
# classification ---- 14250 metric train_loss = 0.0032442877651192247
# classification ---- 14260 metric train_loss = 0.0049774458893807605
# classification ---- 14270 metric train_loss = 0.013384281055186876
# classification ---- 14280 metric train_loss = 0.019810865190811454
# classification ---- 14290 metric train_loss = 0.04990952024236321
# classification ---- 14300 metric train_loss = 0.020521294488571585
# classification ---- 14310 metric train_loss = 0.02288727622362785
# classification ---- 14320 metric train_loss = 0.04119435281027108
# classification ---- 14330 metric train_loss = 0.021843197289854288
# classification ---- 14340 metric train_loss = 0.03733261805027723
# classification ---- 14350 metric train_loss = 0.01907415734604001
# classification ---- 14360 metric train_loss = 0.029768790188245475
# classification ---- 14370 metric train_loss = 0.009656779782380909
# classification ---- 14380 metric train_loss = 0.015844590263441205
# classification ---- 14390 metric train_loss = 0.030811907397583126
# classification ---- 14400 metric train_loss = 0.02332187826395966
# classification ---- 14410 metric train_loss = 0.029750419477932156
# classification ---- 14420 metric train_loss = 0.023100884212180973
# classification ---- 14430 metric train_loss = 0.03343867314979434
# classification ---- 14440 metric train_loss = 0.019157522125169635
# classification ---- 14450 metric train_loss = 0.03825302191544324
# classification ---- 14460 metric train_loss = 0.01215143246226944
# classification ---- 14470 metric train_loss = 0.022783883748343215
# classification ---- 14480 metric train_loss = 0.019839888089336455
# classification ---- 14490 metric train_loss = 0.009334469796158373
# classification ---- 14500 metric train_loss = 0.010385918452811893
# classification ---- 30 metric test_f1 = 0.9431478598960121
# classification ---- 14510 metric train_loss = 0.004292026913026348
# classification ---- 14520 metric train_loss = 0.01716457001166418
# classification ---- 14530 metric train_loss = 0.011507317866198718
# classification ---- 14540 metric train_loss = 0.018802421822329052
# classification ---- 14550 metric train_loss = 0.01743214873713441
# classification ---- 14560 metric train_loss = 0.015603187537635677
# classification ---- 14570 metric train_loss = 0.02997067755786702
# classification ---- 14580 metric train_loss = 0.012966193503234535
# classification ---- 14590 metric train_loss = 0.023137966089416297
# classification ---- 14600 metric train_loss = 0.008669765648664906
# classification ---- 14610 metric train_loss = 0.013927601126488299
# classification ---- 14620 metric train_loss = 0.02857371210702695
# classification ---- 14630 metric train_loss = 0.017144533462123947
# classification ---- 14640 metric train_loss = 0.021025807430851272
# classification ---- 14650 metric train_loss = 0.010228777924203314
# classification ---- 14660 metric train_loss = 0.037533151253592224
# classification ---- 14670 metric train_loss = 0.01824061763472855
# classification ---- 14680 metric train_loss = 0.012804732684162445
# classification ---- 14690 metric train_loss = 0.00555771472863853
# classification ---- 14700 metric train_loss = 0.010598546778783201
# classification ---- 14710 metric train_loss = 0.008589434891473503
# classification ---- 14720 metric train_loss = 0.01082696141093038
# classification ---- 14730 metric train_loss = 0.006445537708350458
# classification ---- 14740 metric train_loss = 0.004226739806472324
# classification ---- 14750 metric train_loss = 0.011269967220141553
# classification ---- 14760 metric train_loss = 0.005677449313225225
# classification ---- 14770 metric train_loss = 0.02402836691471748
# classification ---- 14780 metric train_loss = 0.003892166478181025
# classification ---- 14790 metric train_loss = 0.004542320460313931
# classification ---- 14800 metric train_loss = 0.0030533929922967216
# classification ---- 14810 metric train_loss = 0.015710911923088135
# classification ---- 14820 metric train_loss = 0.011550335615174845
# classification ---- 14830 metric train_loss = 0.010402638086816296
# classification ---- 14840 metric train_loss = 0.0032028011104557664
# classification ---- 14850 metric train_loss = 0.006620094878599048
# classification ---- 14860 metric train_loss = 0.012686912098433822
# classification ---- 14870 metric train_loss = 0.021667697708471677
# classification ---- 14880 metric train_loss = 0.024392877909122035
# classification ---- 14890 metric train_loss = 0.009139278903603554
# classification ---- 14900 metric train_loss = 0.012049469311023131
# classification ---- 14910 metric train_loss = 0.005689818972314242
# classification ---- 14920 metric train_loss = 0.014238717063562945
# classification ---- 14930 metric train_loss = 0.03200962889241055
# classification ---- 14940 metric train_loss = 0.01575856696581468
# classification ---- 14950 metric train_loss = 0.010561770282220096
# classification ---- 14960 metric train_loss = 0.02164944238902535
# classification ---- 14970 metric train_loss = 0.028554215660551562
# classification ---- 14980 metric train_loss = 0.008849102060776205
# classification ---- 14990 metric train_loss = 0.02171503206482157
# classification ---- 15000 metric train_loss = 0.012841660040430724
# classification ---- 31 metric test_f1 = 0.9455736910743024
# classification ---- 16 metric train_f1 = 0.977095182847326
# classification ---- 15010 metric train_loss = 0.008208293234929442
# classification ---- 15020 metric train_loss = 0.006911416375078261
# classification ---- 15030 metric train_loss = 0.02842259103199467
# classification ---- 15040 metric train_loss = 0.008555230776255484
# classification ---- 15050 metric train_loss = 0.03388715082546696
# classification ---- 15060 metric train_loss = 0.018484422913752498
# classification ---- 15070 metric train_loss = 0.011349354064077489
# classification ---- 15080 metric train_loss = 0.016911447211168707
# classification ---- 15090 metric train_loss = 0.008312233560718595
# classification ---- 15100 metric train_loss = 0.009938702281215229
# classification ---- 15110 metric train_loss = 0.013027121650520713
# classification ---- 15120 metric train_loss = 0.02152624967857264
# classification ---- 15130 metric train_loss = 0.012067535909591243
# classification ---- 15140 metric train_loss = 0.030740608705673366
# classification ---- 15150 metric train_loss = 0.0241887298412621
# classification ---- 15160 metric train_loss = 0.00868495394825004
# classification ---- 15170 metric train_loss = 0.019688400090672076
# classification ---- 15180 metric train_loss = 0.014433197455946355
# classification ---- 15190 metric train_loss = 0.01231167366495356
# classification ---- 15200 metric train_loss = 0.009898358100326732
# classification ---- 15210 metric train_loss = 0.013592628098558634
# classification ---- 15220 metric train_loss = 0.012053498183377087
# classification ---- 15230 metric train_loss = 0.014112564641982317
# classification ---- 15240 metric train_loss = 0.012644362600985915
# classification ---- 15250 metric train_loss = 0.006328508589649573
# classification ---- 15260 metric train_loss = 0.01246990318177268
# classification ---- 15270 metric train_loss = 0.015353432192932814
# classification ---- 15280 metric train_loss = 0.012140009109862149
# classification ---- 15290 metric train_loss = 0.036988727891002784
# classification ---- 15300 metric train_loss = 0.012841213005594909
# classification ---- 15310 metric train_loss = 0.02295525631052442
# classification ---- 15320 metric train_loss = 0.014503349037840962
# classification ---- 15330 metric train_loss = 0.01852637194097042
# classification ---- 15340 metric train_loss = 0.01286971383378841
# classification ---- 15350 metric train_loss = 0.009858496618107893
# classification ---- 15360 metric train_loss = 0.023434034147066997
# classification ---- 15370 metric train_loss = 0.01919316026614979
# classification ---- 15380 metric train_loss = 0.02313995169242844

# %%
labels = list(map(lambda x : x["label"], all_test_dataset))

# %%
preds,labels = classification_trainer.predictOnDataset(dataset= all_test_dataset)

# %%
precision_recall_fscore_support(labels,preds,zero_division= 0)
# Out:
# (array([0.80310881, 0.99765488, 0.9995311 , 0.99084489]),
#  array([0.80310881, 0.99843536, 0.99610592, 0.99553219]),
#  array([0.80310881, 0.99804497, 0.99781557, 0.99318301]),
#  array([ 193, 5113, 6420, 3805]))

# %%
sum([0.6978022 , 0.99075786, 0.98024583, 0.98798674])/4
# Out:
# 0.9141981575
