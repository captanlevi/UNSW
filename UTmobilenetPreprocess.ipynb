# %%
"""
@author: Yuqiang (Ethan) Heng
"""
import numpy as np
import pandas as pd
from tqdm import tqdm
from os import listdir
from os.path import isfile, join

scenario = 'random' #deterministic, random or wild
if scenario == 'random':
    mypath = 'data/UTMobileNet2021/Randomized Automated Data'
elif scenario == 'deterministic':
    mypath = 'data/UTMobileNet2021/Deterministic Automated Data'
elif scenario == 'wild':
    mypath = 'data/UTMobileNet2021/Wild Test Data'
else:
    raise NameError('Dataset Not Supported')

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
apps = np.unique([f.split('_')[0] for f in onlyfiles])
print(apps, len(apps), len(onlyfiles))
app_actions = np.unique(['_'.join(f.split('_')[:2]) for f in onlyfiles])
print(app_actions, len(app_actions))

sel_apps = apps
sel_app_files = {i:[] for i in sel_apps}

for fname in onlyfiles:
    app_name = fname.split('_')[0]
    if app_name in sel_apps:
        sel_app_files[app_name].append(fname)
# Out:
# ['dropbox' 'facebook' 'gmail' 'google-drive' 'hulu' 'instagram'
#  'messenger' 'netflix' 'pandora' 'pinterest' 'reddit' 'spotify' 'twitter'
#  'youtube'] 14 288
# ['dropbox_download' 'dropbox_upload' 'facebook_scroll-newsfeed'
#  'facebook_search-page' 'gmail_open-email' 'gmail_send-email'
#  'google-drive_download' 'google-drive_upload' 'hulu_scroll-home'
#  'hulu_watch-video' 'instagram_IgSearchBrowse' 'instagram_send-message'
#  'messenger_send-message' 'netflix_browse-home' 'netflix_watch-video'
#  'pandora_play-music' 'pandora_search-music' 'pinterest_tap-board'
#  'reddit_browse' 'reddit_post' 'spotify_play-music' 'spotify_search-music'
#  'twitter_post-tweet' 'twitter_scroll-feed' 'twitter_send-message'
#  'youtube_play-video' 'youtube_search'] 27

# %%
flow_columns = ['ip.src', 'srcport', 'ip.dst', 'dstport', 'protocal']

def get_protocal(row):
    if not pd.isnull(row['tcp.len']):
        return 'TCP'
    elif not pd.isnull(row['udp.length']):
        return 'UDP'
    else:
        return 'Unknown'
    
def get_srt_port(row):
    if not pd.isnull(row['tcp.len']):
        return row['tcp.srcport']
    elif not pd.isnull(row['udp.length']):
        return row['udp.srcport']
    else:
        return 'Unknown'
    
def get_dst_port(row):
    if not pd.isnull(row['tcp.len']):
        return row['tcp.dstport']
    elif not pd.isnull(row['udp.length']):
        return row['udp.dstport']
    else:
        return 'Unknown'
    
columns = ['frame.number','frame.time','frame.len','frame.cap_len','ip.hdr_len',
           'ip.dsfield.ecn','ip.len','ip.frag_offset','ip.ttl','ip.proto','ip.src',
           'ip.dst','tcp.hdr_len','tcp.len','tcp.srcport','tcp.dstport','tcp.flags.ns',
           'tcp.flags.fin','tcp.window_size_value','tcp.urgent_pointer','tcp.option_kind',
           'tcp.option_len','udp.srcport','udp.dstport','udp.length']

def compute_flow_features(df):
    flow_features = {}
    flow_features['total_num_pkts'] = len(df)
    pkt_size = df['ip.len'].astype(float)
    flow_features['total_num_bytes'] = pkt_size.sum()
    flow_features['min_pkt_size'] = pkt_size.min()
    flow_features['max_pkt_size'] = pkt_size.max()
    flow_features['mean_pkt_size'] = pkt_size.mean()
    flow_features['std_pkt_size'] = pkt_size.std()
    # pd.to_datetime(df["frame.time"].apply(lambda x : x.replace("CDT","").replace("CST","").strip()))
    iat = pd.to_datetime(df['frame.time'].apply(lambda x : x.replace("CDT","").replace("CST","").strip())).diff(1).dt.total_seconds().iloc[1:]
    flow_features['min_iat'] = iat.min()
    flow_features['max_iat'] = iat.max()
    flow_features['mean_iat'] = iat.mean()
    flow_features['std_iat'] = iat.std()
    flow_features['dur'] = iat.sum()
    return flow_features

def process_df_by_flow(df):
    df['protocal'] = df.apply(lambda row: get_protocal(row), axis=1)
    df['srcport'] = df.apply(lambda row: get_srt_port(row), axis=1)
    df['dstport'] = df.apply(lambda row: get_dst_port(row), axis=1)  
    df_flow = pd.DataFrame()
    flow_columns = ['ip.src', 'srcport', 'ip.dst', 'dstport', 'protocal']
    ul_flows = {}
    dl_flows = {}
    for flow, flow_df in df.groupby(by=flow_columns):
        print(flow)
        print(flow_df)
        if flow[0].split('.')[0] == '10':
            ul_flows[flow] = compute_flow_features(flow_df)
        else:
            dl_flows[flow] = compute_flow_features(flow_df)
    for ul_flow, ul_flow_features in ul_flows.items():
        for dl_flow, dl_flow_features in dl_flows.items():
            if (ul_flow[0] == dl_flow[2]) & (ul_flow[2] == dl_flow[0]) & (ul_flow[1] == dl_flow[3]) & (ul_flow[3] == dl_flow[1]) & (ul_flow[4] == dl_flow[4]):
                ul_flow_features = {'ul_'+feature_name:feature for feature_name,feature in ul_flow_features.items()}
                dl_flow_features = {'dl_'+feature_name:feature for feature_name,feature in dl_flow_features.items()}
                bi_flow_features = {**ul_flow_features,**dl_flow_features}
                bi_flow_features['ip_A'] = ul_flow[0]
                bi_flow_features['port_A'] = ul_flow[1]
                bi_flow_features['ip_B'] = ul_flow[2]
                bi_flow_features['port_B'] = ul_flow[3]
                bi_flow_features['protocal'] = ul_flow[4]
                print(bi_flow_features)
                df_flow = pd.concat([df_flow,pd.DataFrame(bi_flow_features)],ignore_index= True)#df_flow.append(bi_flow_features, ignore_index=True)
    return df_flow

def clean_up_duplicate(row):
    if len(str(row['ip.hdr_len']).split(','))>1:
        row['ip.hdr_len'] = str(row['ip.hdr_len']).split(',')[1]
    if len(str(row['ip.len']).split(','))>1:
        row['ip.len'] = str(row['ip.len']).split(',')[1]
    else:
        row['ip.len'] = str(row['ip.len']).split(',')[0]
    if len(row['ip.src'].split(','))>1:
        row['ip.src'] = row['ip.src'].split(',')[1]
    if len(row['ip.dst'].split(','))>1:
        row['ip.dst'] = row['ip.dst'].split(',')[1]
    return row

# %%
df_all = pd.DataFrame()
for app in sel_apps:
    integrity = True
    df_app = pd.DataFrame()
    for fname in sel_app_files[app]:
        action = fname.split('_')[1]
        df = pd.read_csv(join(mypath,fname),usecols = columns,low_memory=False)
        df = df[df['ip.src'].notna()]
        
        df = df.apply(lambda row:clean_up_duplicate(row),axis=1)
        
        # Remove self loop pkts
        df = df[(df['ip.src']!='127.0.0.1') & (df['ip.dst']!='127.0.0.1')]
        try:
            df_flow = process_df_by_flow(df)
            df_flow['action'] = action
            df_app = pd.concat([df_app,df_flow])#df_app.append(df_flow)
            assert False
        except Exception as e:
            print(e)
            integrity = False
            print('\n Error while processing {}. \n'.format(fname))
            assert False

    df_app['app'] = app
    
    if integrity:
        df_all = df_all.append(df_app)
        
#df_all.to_csv('./Processed Data/{}_scenario_bi_flow_features.csv'.format(scenario))
print('Finished processing {} scenario data.'.format(scenario))
# Out:
# ('10.146.66.8', 37879.0, '162.125.18.133', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 172           173  Apr 30, 2019 08:20:34.125882000 CDT         76
# 178           179  Apr 30, 2019 08:20:34.168755000 CDT         68
# 179           180  Apr 30, 2019 08:20:34.169692000 CDT        237
# 188           189  Apr 30, 2019 08:20:34.213768000 CDT         68
# 190           191  Apr 30, 2019 08:20:34.213866000 CDT         68
# 192           193  Apr 30, 2019 08:20:34.213913000 CDT         68
# 196           197  Apr 30, 2019 08:20:34.272388000 CDT        161
# 198           199  Apr 30, 2019 08:20:34.316007000 CDT        207
# 206           207  Apr 30, 2019 08:20:34.354660000 CDT         68
# 208           209  Apr 30, 2019 08:20:34.359010000 CDT        846
# 212           213  Apr 30, 2019 08:20:34.441134000 CDT         68
# 233           234  Apr 30, 2019 08:20:41.945830000 CDT        110
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 172             76        20.0             0.0   60.0             0.0    64.0
# 178             68        20.0             0.0   52.0             0.0    64.0
# 179             68        20.0             0.0  221.0             0.0    64.0
# 188             68        20.0             0.0   52.0             0.0    64.0
# 190             68        20.0             0.0   52.0             0.0    64.0
# 192             68        20.0             0.0   52.0             0.0    64.0
# 196             68        20.0             0.0  145.0             0.0    64.0
# 198             68        20.0             0.0  191.0             0.0    64.0
# 206             68        20.0             0.0   52.0             0.0    64.0
# 208             68        20.0             0.0  830.0             0.0    64.0
# 212             68        20.0             0.0   52.0             0.0    64.0
# 233             68        20.0             0.0   94.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 172       6.0  ...               65535.0                0.0        2,4,8,1,3
# 178       6.0  ...                 343.0                0.0            1,1,8
# 179       6.0  ...                 343.0                0.0            1,1,8
# 188       6.0  ...                 354.0                0.0            1,1,8
# 190       6.0  ...                 365.0                0.0            1,1,8
# 192       6.0  ...                 375.0                0.0            1,1,8
# 196       6.0  ...                 375.0                0.0            1,1,8
# 198       6.0  ...                 385.0                0.0            1,1,8
# 206       6.0  ...                 385.0                0.0            1,1,8
# 208       6.0  ...                 385.0                0.0            1,1,8
# 212       6.0  ...                 385.0                0.0            1,1,8
# 233       6.0  ...                 385.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 172        4,2,10,3          NaN          NaN         NaN       TCP  37879.0
# 178              10          NaN          NaN         NaN       TCP  37879.0
# 179              10          NaN          NaN         NaN       TCP  37879.0
# 188              10          NaN          NaN         NaN       TCP  37879.0
# 190              10          NaN          NaN         NaN       TCP  37879.0
# 192              10          NaN          NaN         NaN       TCP  37879.0
# 196              10          NaN          NaN         NaN       TCP  37879.0
# 198              10          NaN          NaN         NaN       TCP  37879.0
# 206              10          NaN          NaN         NaN       TCP  37879.0
# 208              10          NaN          NaN         NaN       TCP  37879.0
# 212              10          NaN          NaN         NaN       TCP  37879.0
# 233              10          NaN          NaN         NaN       TCP  37879.0
#
#      dstport
# 172    443.0
# 178    443.0
# 179    443.0
# 188    443.0
# 190    443.0
# 192    443.0
# 196    443.0
# 198    443.0
# 206    443.0
# 208    443.0
# 212    443.0
# 233    443.0
#
# [12 rows x 28 columns]
# ('10.146.66.8', 39366.0, '128.83.185.41', 53.0, 'UDP')
#      frame.number                           frame.time  frame.len  \
# 169           170  Apr 30, 2019 08:20:34.117963000 CDT         78
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 169             44        20.0             0.0   62.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 169      17.0  ...                   NaN                NaN              NaN
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 169             NaN      39366.0         53.0        42.0       UDP  39366.0
#
#      dstport
# 169     53.0
#
# [1 rows x 28 columns]
# ('10.146.66.8', 41859.0, '128.83.185.41', 53.0, 'UDP')
#    frame.number                           frame.time  frame.len  \
# 1             2  Apr 30, 2019 08:20:33.398450000 CDT         77
#
#    frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 1             44        20.0             0.0   61.0             0.0    64.0
#
#    ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 1      17.0  ...                   NaN                NaN              NaN
#
#    tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 1             NaN      41859.0         53.0        41.0       UDP  41859.0
#
#    dstport
# 1     53.0
#
# [1 rows x 28 columns]
# ('10.146.66.8', 44346.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 3               4  Apr 30, 2019 08:20:33.405700000 CDT         76
# 5               6  Apr 30, 2019 08:20:33.414825000 CDT         68
# 6               7  Apr 30, 2019 08:20:33.416163000 CDT        225
# 9              10  Apr 30, 2019 08:20:33.427159000 CDT         68
# 11             12  Apr 30, 2019 08:20:33.428929000 CDT         68
# 13             14  Apr 30, 2019 08:20:33.428993000 CDT         68
# 15             16  Apr 30, 2019 08:20:33.429046000 CDT         68
# 29             30  Apr 30, 2019 08:20:33.468964000 CDT        161
# 33             34  Apr 30, 2019 08:20:33.478157000 CDT         68
# 35             36  Apr 30, 2019 08:20:33.481180000 CDT        574
# 63             64  Apr 30, 2019 08:20:33.601777000 CDT         68
# 132           133  Apr 30, 2019 08:20:33.916117000 CDT        574
# 162           163  Apr 30, 2019 08:20:34.055013000 CDT         68
# 176           177  Apr 30, 2019 08:20:34.168303000 CDT        575
# 205           206  Apr 30, 2019 08:20:34.345047000 CDT         68
# 209           210  Apr 30, 2019 08:20:34.391492000 CDT        623
# 217           218  Apr 30, 2019 08:20:34.511759000 CDT         68
# 228           229  Apr 30, 2019 08:20:41.454652000 CDT        577
# 232           233  Apr 30, 2019 08:20:41.547504000 CDT         68
# 269           270  Apr 30, 2019 08:21:01.548535000 CDT         99
# 270           271  Apr 30, 2019 08:21:01.549700000 CDT         68
# 272           273  Apr 30, 2019 08:21:01.572554000 CDT         68
# 274           275  Apr 30, 2019 08:21:01.575064000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 3               76        20.0             0.0   60.0             0.0    64.0
# 5               68        20.0             0.0   52.0             0.0    64.0
# 6               68        20.0             0.0  209.0             0.0    64.0
# 9               68        20.0             0.0   52.0             0.0    64.0
# 11              68        20.0             0.0   52.0             0.0    64.0
# 13              68        20.0             0.0   52.0             0.0    64.0
# 15              68        20.0             0.0   52.0             0.0    64.0
# 29              68        20.0             0.0  145.0             0.0    64.0
# 33              68        20.0             0.0   52.0             0.0    64.0
# 35              68        20.0             0.0  558.0             0.0    64.0
# 63              68        20.0             0.0   52.0             0.0    64.0
# 132             68        20.0             0.0  558.0             0.0    64.0
# 162             68        20.0             0.0   52.0             0.0    64.0
# 176             68        20.0             0.0  559.0             0.0    64.0
# 205             68        20.0             0.0   52.0             0.0    64.0
# 209             68        20.0             0.0  607.0             0.0    64.0
# 217             68        20.0             0.0   52.0             0.0    64.0
# 228             68        20.0             0.0  561.0             0.0    64.0
# 232             68        20.0             0.0   52.0             0.0    64.0
# 269             68        20.0             0.0   83.0             0.0    64.0
# 270             68        20.0             0.0   52.0             0.0    64.0
# 272             68        20.0             0.0   52.0             0.0    64.0
# 274             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 3         6.0  ...               65535.0                0.0        2,4,8,1,3
# 5         6.0  ...                 343.0                0.0            1,1,8
# 6         6.0  ...                 343.0                0.0            1,1,8
# 9         6.0  ...                 354.0                0.0            1,1,8
# 11        6.0  ...                 365.0                0.0            1,1,8
# 13        6.0  ...                 377.0                0.0            1,1,8
# 15        6.0  ...                 386.0                0.0            1,1,8
# 29        6.0  ...                 386.0                0.0            1,1,8
# 33        6.0  ...                 386.0                0.0            1,1,8
# 35        6.0  ...                 386.0                0.0            1,1,8
# 63        6.0  ...                 396.0                0.0            1,1,8
# 132       6.0  ...                 396.0                0.0            1,1,8
# 162       6.0  ...                 406.0                0.0            1,1,8
# 176       6.0  ...                 406.0                0.0            1,1,8
# 205       6.0  ...                 415.0                0.0            1,1,8
# 209       6.0  ...                 415.0                0.0            1,1,8
# 217       6.0  ...                 425.0                0.0            1,1,8
# 228       6.0  ...                 425.0                0.0            1,1,8
# 232       6.0  ...                 435.0                0.0            1,1,8
# 269       6.0  ...                 435.0                0.0            1,1,8
# 270       6.0  ...                 435.0                0.0            1,1,8
# 272       6.0  ...                 435.0                0.0            1,1,8
# 274       6.0  ...                 435.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 3          4,2,10,3          NaN          NaN         NaN       TCP  44346.0
# 5                10          NaN          NaN         NaN       TCP  44346.0
# 6                10          NaN          NaN         NaN       TCP  44346.0
# 9                10          NaN          NaN         NaN       TCP  44346.0
# 11               10          NaN          NaN         NaN       TCP  44346.0
# 13               10          NaN          NaN         NaN       TCP  44346.0
# 15               10          NaN          NaN         NaN       TCP  44346.0
# 29               10          NaN          NaN         NaN       TCP  44346.0
# 33               10          NaN          NaN         NaN       TCP  44346.0
# 35               10          NaN          NaN         NaN       TCP  44346.0
# 63               10          NaN          NaN         NaN       TCP  44346.0
# 132              10          NaN          NaN         NaN       TCP  44346.0
# 162              10          NaN          NaN         NaN       TCP  44346.0
# 176              10          NaN          NaN         NaN       TCP  44346.0
# 205              10          NaN          NaN         NaN       TCP  44346.0
# 209              10          NaN          NaN         NaN       TCP  44346.0
# 217              10          NaN          NaN         NaN       TCP  44346.0
# 228              10          NaN          NaN         NaN       TCP  44346.0
# 232              10          NaN          NaN         NaN       TCP  44346.0
# 269              10          NaN          NaN         NaN       TCP  44346.0
# 270              10          NaN          NaN         NaN       TCP  44346.0
# 272              10          NaN          NaN         NaN       TCP  44346.0
# 274              10          NaN          NaN         NaN       TCP  44346.0
#
#      dstport
# 3      443.0
# 5      443.0
# 6      443.0
# 9      443.0
# 11     443.0
# 13     443.0
# 15     443.0
# 29     443.0
# 33     443.0
# 35     443.0
# 63     443.0
# 132    443.0
# 162    443.0
# 176    443.0
# 205    443.0
# 209    443.0
# 217    443.0
# 228    443.0
# 232    443.0
# 269    443.0
# 270    443.0
# 272    443.0
# 274    443.0
#
# [23 rows x 28 columns]
# ('10.146.66.8', 44347.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 16             17  Apr 30, 2019 08:20:33.439309000 CDT         76
# 18             19  Apr 30, 2019 08:20:33.448961000 CDT         68
# 19             20  Apr 30, 2019 08:20:33.449582000 CDT        225
# 22             23  Apr 30, 2019 08:20:33.463389000 CDT         68
# 24             25  Apr 30, 2019 08:20:33.463458000 CDT         68
# 26             27  Apr 30, 2019 08:20:33.463506000 CDT         68
# 28             29  Apr 30, 2019 08:20:33.463555000 CDT         68
# 30             31  Apr 30, 2019 08:20:33.474731000 CDT        161
# 37             38  Apr 30, 2019 08:20:33.485614000 CDT        577
# 60             61  Apr 30, 2019 08:20:33.571394000 CDT         68
# 139           140  Apr 30, 2019 08:20:33.956150000 CDT        599
# 175           176  Apr 30, 2019 08:20:34.146674000 CDT         68
# 184           185  Apr 30, 2019 08:20:34.190841000 CDT        599
# 204           205  Apr 30, 2019 08:20:34.334765000 CDT         68
# 213           214  Apr 30, 2019 08:20:34.454188000 CDT        586
# 220           221  Apr 30, 2019 08:20:34.556946000 CDT         68
# 256           257  Apr 30, 2019 08:20:54.561633000 CDT         99
# 257           258  Apr 30, 2019 08:20:54.562696000 CDT         68
# 259           260  Apr 30, 2019 08:20:54.586485000 CDT         68
# 261           262  Apr 30, 2019 08:20:54.589007000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 16              76        20.0             0.0   60.0             0.0    64.0
# 18              68        20.0             0.0   52.0             0.0    64.0
# 19              68        20.0             0.0  209.0             0.0    64.0
# 22              68        20.0             0.0   52.0             0.0    64.0
# 24              68        20.0             0.0   52.0             0.0    64.0
# 26              68        20.0             0.0   52.0             0.0    64.0
# 28              68        20.0             0.0   52.0             0.0    64.0
# 30              68        20.0             0.0  145.0             0.0    64.0
# 37              68        20.0             0.0  561.0             0.0    64.0
# 60              68        20.0             0.0   52.0             0.0    64.0
# 139             68        20.0             0.0  583.0             0.0    64.0
# 175             68        20.0             0.0   52.0             0.0    64.0
# 184             68        20.0             0.0  583.0             0.0    64.0
# 204             68        20.0             0.0   52.0             0.0    64.0
# 213             68        20.0             0.0  570.0             0.0    64.0
# 220             68        20.0             0.0   52.0             0.0    64.0
# 256             68        20.0             0.0   83.0             0.0    64.0
# 257             68        20.0             0.0   52.0             0.0    64.0
# 259             68        20.0             0.0   52.0             0.0    64.0
# 261             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 16        6.0  ...               65535.0                0.0        2,4,8,1,3
# 18        6.0  ...                 343.0                0.0            1,1,8
# 19        6.0  ...                 343.0                0.0            1,1,8
# 22        6.0  ...                 354.0                0.0            1,1,8
# 24        6.0  ...                 365.0                0.0            1,1,8
# 26        6.0  ...                 377.0                0.0            1,1,8
# 28        6.0  ...                 386.0                0.0            1,1,8
# 30        6.0  ...                 386.0                0.0            1,1,8
# 37        6.0  ...                 386.0                0.0            1,1,8
# 60        6.0  ...                 396.0                0.0            1,1,8
# 139       6.0  ...                 396.0                0.0            1,1,8
# 175       6.0  ...                 406.0                0.0            1,1,8
# 184       6.0  ...                 406.0                0.0            1,1,8
# 204       6.0  ...                 415.0                0.0            1,1,8
# 213       6.0  ...                 415.0                0.0            1,1,8
# 220       6.0  ...                 425.0                0.0            1,1,8
# 256       6.0  ...                 425.0                0.0            1,1,8
# 257       6.0  ...                 425.0                0.0            1,1,8
# 259       6.0  ...                 425.0                0.0            1,1,8
# 261       6.0  ...                 425.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 16         4,2,10,3          NaN          NaN         NaN       TCP  44347.0
# 18               10          NaN          NaN         NaN       TCP  44347.0
# 19               10          NaN          NaN         NaN       TCP  44347.0
# 22               10          NaN          NaN         NaN       TCP  44347.0
# 24               10          NaN          NaN         NaN       TCP  44347.0
# 26               10          NaN          NaN         NaN       TCP  44347.0
# 28               10          NaN          NaN         NaN       TCP  44347.0
# 30               10          NaN          NaN         NaN       TCP  44347.0
# 37               10          NaN          NaN         NaN       TCP  44347.0
# 60               10          NaN          NaN         NaN       TCP  44347.0
# 139              10          NaN          NaN         NaN       TCP  44347.0
# 175              10          NaN          NaN         NaN       TCP  44347.0
# 184              10          NaN          NaN         NaN       TCP  44347.0
# 204              10          NaN          NaN         NaN       TCP  44347.0
# 213              10          NaN          NaN         NaN       TCP  44347.0
# 220              10          NaN          NaN         NaN       TCP  44347.0
# 256              10          NaN          NaN         NaN       TCP  44347.0
# 257              10          NaN          NaN         NaN       TCP  44347.0
# 259              10          NaN          NaN         NaN       TCP  44347.0
# 261              10          NaN          NaN         NaN       TCP  44347.0
#
#      dstport
# 16     443.0
# 18     443.0
# 19     443.0
# 22     443.0
# 24     443.0
# 26     443.0
# 28     443.0
# 30     443.0
# 37     443.0
# 60     443.0
# 139    443.0
# 175    443.0
# 184    443.0
# 204    443.0
# 213    443.0
# 220    443.0
# 256    443.0
# 257    443.0
# 259    443.0
# 261    443.0
#
# [20 rows x 28 columns]
# ('10.146.66.8', 44348.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 34             35  Apr 30, 2019 08:20:33.478662000 CDT         76
# 39             40  Apr 30, 2019 08:20:33.487606000 CDT         68
# 40             41  Apr 30, 2019 08:20:33.488799000 CDT        236
# 43             44  Apr 30, 2019 08:20:33.500861000 CDT         68
# 45             46  Apr 30, 2019 08:20:33.501265000 CDT         68
# 47             48  Apr 30, 2019 08:20:33.501948000 CDT         68
# 49             50  Apr 30, 2019 08:20:33.502004000 CDT         68
# 52             53  Apr 30, 2019 08:20:33.548370000 CDT        161
# 54             55  Apr 30, 2019 08:20:33.558178000 CDT         68
# 56             57  Apr 30, 2019 08:20:33.558237000 CDT         68
# 57             58  Apr 30, 2019 08:20:33.560564000 CDT        121
# 65             66  Apr 30, 2019 08:20:33.612236000 CDT        676
# 69             70  Apr 30, 2019 08:20:33.661092000 CDT         68
# 102           103  Apr 30, 2019 08:20:33.731434000 CDT         68
# 104           105  Apr 30, 2019 08:20:33.731494000 CDT         68
# 124           125  Apr 30, 2019 08:20:33.859741000 CDT        221
# 157           158  Apr 30, 2019 08:20:34.038567000 CDT         68
# 159           160  Apr 30, 2019 08:20:34.038633000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 34              76        20.0             0.0   60.0             0.0    64.0
# 39              68        20.0             0.0   52.0             0.0    64.0
# 40              68        20.0             0.0  220.0             0.0    64.0
# 43              68        20.0             0.0   52.0             0.0    64.0
# 45              68        20.0             0.0   52.0             0.0    64.0
# 47              68        20.0             0.0   52.0             0.0    64.0
# 49              68        20.0             0.0   52.0             0.0    64.0
# 52              68        20.0             0.0  145.0             0.0    64.0
# 54              68        20.0             0.0   52.0             0.0    64.0
# 56              68        20.0             0.0   52.0             0.0    64.0
# 57              68        20.0             0.0  105.0             0.0    64.0
# 65              68        20.0             0.0  660.0             0.0    64.0
# 69              68        20.0             0.0   52.0             0.0    64.0
# 102             68        20.0             0.0   52.0             0.0    64.0
# 104             68        20.0             0.0   52.0             0.0    64.0
# 124             68        20.0             0.0  205.0             0.0    64.0
# 157             68        20.0             0.0   52.0             0.0    64.0
# 159             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 34        6.0  ...               65535.0                0.0        2,4,8,1,3
# 39        6.0  ...                 343.0                0.0            1,1,8
# 40        6.0  ...                 343.0                0.0            1,1,8
# 43        6.0  ...                 354.0                0.0            1,1,8
# 45        6.0  ...                 365.0                0.0            1,1,8
# 47        6.0  ...                 377.0                0.0            1,1,8
# 49        6.0  ...                 386.0                0.0            1,1,8
# 52        6.0  ...                 386.0                0.0            1,1,8
# 54        6.0  ...                 396.0                0.0            1,1,8
# 56        6.0  ...                 396.0                0.0            1,1,8
# 57        6.0  ...                 396.0                0.0            1,1,8
# 65        6.0  ...                 396.0                0.0            1,1,8
# 69        6.0  ...                 396.0                0.0            1,1,8
# 102       6.0  ...                 406.0                0.0            1,1,8
# 104       6.0  ...                 406.0                0.0            1,1,8
# 124       6.0  ...                 406.0                0.0            1,1,8
# 157       6.0  ...                 415.0                0.0            1,1,8
# 159       6.0  ...                 415.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 34         4,2,10,3          NaN          NaN         NaN       TCP  44348.0
# 39               10          NaN          NaN         NaN       TCP  44348.0
# 40               10          NaN          NaN         NaN       TCP  44348.0
# 43               10          NaN          NaN         NaN       TCP  44348.0
# 45               10          NaN          NaN         NaN       TCP  44348.0
# 47               10          NaN          NaN         NaN       TCP  44348.0
# 49               10          NaN          NaN         NaN       TCP  44348.0
# 52               10          NaN          NaN         NaN       TCP  44348.0
# 54               10          NaN          NaN         NaN       TCP  44348.0
# 56               10          NaN          NaN         NaN       TCP  44348.0
# 57               10          NaN          NaN         NaN       TCP  44348.0
# 65               10          NaN          NaN         NaN       TCP  44348.0
# 69               10          NaN          NaN         NaN       TCP  44348.0
# 102              10          NaN          NaN         NaN       TCP  44348.0
# 104              10          NaN          NaN         NaN       TCP  44348.0
# 124              10          NaN          NaN         NaN       TCP  44348.0
# 157              10          NaN          NaN         NaN       TCP  44348.0
# 159              10          NaN          NaN         NaN       TCP  44348.0
#
#      dstport
# 34     443.0
# 39     443.0
# 40     443.0
# 43     443.0
# 45     443.0
# 47     443.0
# 49     443.0
# 52     443.0
# 54     443.0
# 56     443.0
# 57     443.0
# 65     443.0
# 69     443.0
# 102    443.0
# 104    443.0
# 124    443.0
# 157    443.0
# 159    443.0
#
# [18 rows x 28 columns]
# ('10.146.66.8', 44349.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 68             69  Apr 30, 2019 08:20:33.656806000 CDT         76
# 72             73  Apr 30, 2019 08:20:33.665802000 CDT         68
# 73             74  Apr 30, 2019 08:20:33.666421000 CDT        222
# 79             80  Apr 30, 2019 08:20:33.677037000 CDT         68
# 81             82  Apr 30, 2019 08:20:33.678788000 CDT         68
# 83             84  Apr 30, 2019 08:20:33.678848000 CDT         68
# 85             86  Apr 30, 2019 08:20:33.678896000 CDT         68
# 95             96  Apr 30, 2019 08:20:33.692503000 CDT        161
# 98             99  Apr 30, 2019 08:20:33.703205000 CDT        823
# 114           115  Apr 30, 2019 08:20:33.818574000 CDT         68
# 135           136  Apr 30, 2019 08:20:33.951321000 CDT        626
# 166           167  Apr 30, 2019 08:20:34.106237000 CDT         68
# 221           222  Apr 30, 2019 08:20:38.528871000 CDT        866
# 225           226  Apr 30, 2019 08:20:38.702652000 CDT         68
# 264           265  Apr 30, 2019 08:20:58.703762000 CDT         99
# 265           266  Apr 30, 2019 08:20:58.705156000 CDT         68
# 268           269  Apr 30, 2019 08:20:58.741824000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 68              76        20.0             0.0   60.0             0.0    64.0
# 72              68        20.0             0.0   52.0             0.0    64.0
# 73              68        20.0             0.0  206.0             0.0    64.0
# 79              68        20.0             0.0   52.0             0.0    64.0
# 81              68        20.0             0.0   52.0             0.0    64.0
# 83              68        20.0             0.0   52.0             0.0    64.0
# 85              68        20.0             0.0   52.0             0.0    64.0
# 95              68        20.0             0.0  145.0             0.0    64.0
# 98              68        20.0             0.0  807.0             0.0    64.0
# 114             68        20.0             0.0   52.0             0.0    64.0
# 135             68        20.0             0.0  610.0             0.0    64.0
# 166             68        20.0             0.0   52.0             0.0    64.0
# 221             68        20.0             0.0  850.0             0.0    64.0
# 225             68        20.0             0.0   52.0             0.0    64.0
# 264             68        20.0             0.0   83.0             0.0    64.0
# 265             68        20.0             0.0   52.0             0.0    64.0
# 268             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 68        6.0  ...               65535.0                0.0        2,4,8,1,3
# 72        6.0  ...                 343.0                0.0            1,1,8
# 73        6.0  ...                 343.0                0.0            1,1,8
# 79        6.0  ...                 354.0                0.0            1,1,8
# 81        6.0  ...                 365.0                0.0            1,1,8
# 83        6.0  ...                 377.0                0.0            1,1,8
# 85        6.0  ...                 386.0                0.0            1,1,8
# 95        6.0  ...                 386.0                0.0            1,1,8
# 98        6.0  ...                 386.0                0.0            1,1,8
# 114       6.0  ...                 396.0                0.0            1,1,8
# 135       6.0  ...                 396.0                0.0            1,1,8
# 166       6.0  ...                 406.0                0.0            1,1,8
# 221       6.0  ...                 406.0                0.0            1,1,8
# 225       6.0  ...                 415.0                0.0            1,1,8
# 264       6.0  ...                 415.0                0.0            1,1,8
# 265       6.0  ...                 415.0                0.0            1,1,8
# 268       6.0  ...                 415.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 68         4,2,10,3          NaN          NaN         NaN       TCP  44349.0
# 72               10          NaN          NaN         NaN       TCP  44349.0
# 73               10          NaN          NaN         NaN       TCP  44349.0
# 79               10          NaN          NaN         NaN       TCP  44349.0
# 81               10          NaN          NaN         NaN       TCP  44349.0
# 83               10          NaN          NaN         NaN       TCP  44349.0
# 85               10          NaN          NaN         NaN       TCP  44349.0
# 95               10          NaN          NaN         NaN       TCP  44349.0
# 98               10          NaN          NaN         NaN       TCP  44349.0
# 114              10          NaN          NaN         NaN       TCP  44349.0
# 135              10          NaN          NaN         NaN       TCP  44349.0
# 166              10          NaN          NaN         NaN       TCP  44349.0
# 221              10          NaN          NaN         NaN       TCP  44349.0
# 225              10          NaN          NaN         NaN       TCP  44349.0
# 264              10          NaN          NaN         NaN       TCP  44349.0
# 265              10          NaN          NaN         NaN       TCP  44349.0
# 268              10          NaN          NaN         NaN       TCP  44349.0
#
#      dstport
# 68     443.0
# 72     443.0
# 73     443.0
# 79     443.0
# 81     443.0
# 83     443.0
# 85     443.0
# 95     443.0
# 98     443.0
# 114    443.0
# 135    443.0
# 166    443.0
# 221    443.0
# 225    443.0
# 264    443.0
# 265    443.0
# 268    443.0
#
# [17 rows x 28 columns]
# ('10.146.66.8', 44350.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 70             71  Apr 30, 2019 08:20:33.662987000 CDT         76
# 75             76  Apr 30, 2019 08:20:33.672208000 CDT         68
# 76             77  Apr 30, 2019 08:20:33.672772000 CDT        222
# 88             89  Apr 30, 2019 08:20:33.684135000 CDT         68
# 90             91  Apr 30, 2019 08:20:33.685989000 CDT         68
# 92             93  Apr 30, 2019 08:20:33.686053000 CDT         68
# 94             95  Apr 30, 2019 08:20:33.686102000 CDT         68
# 96             97  Apr 30, 2019 08:20:33.698132000 CDT        161
# 100           101  Apr 30, 2019 08:20:33.709141000 CDT        928
# 129           130  Apr 30, 2019 08:20:33.907975000 CDT         68
# 141           142  Apr 30, 2019 08:20:33.960953000 CDT        842
# 183           184  Apr 30, 2019 08:20:34.181895000 CDT         68
# 242           243  Apr 30, 2019 08:20:54.182835000 CDT         99
# 243           244  Apr 30, 2019 08:20:54.183865000 CDT         68
# 245           246  Apr 30, 2019 08:20:54.195176000 CDT         68
# 247           248  Apr 30, 2019 08:20:54.196065000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 70              76        20.0             0.0   60.0             0.0    64.0
# 75              68        20.0             0.0   52.0             0.0    64.0
# 76              68        20.0             0.0  206.0             0.0    64.0
# 88              68        20.0             0.0   52.0             0.0    64.0
# 90              68        20.0             0.0   52.0             0.0    64.0
# 92              68        20.0             0.0   52.0             0.0    64.0
# 94              68        20.0             0.0   52.0             0.0    64.0
# 96              68        20.0             0.0  145.0             0.0    64.0
# 100             68        20.0             0.0  912.0             0.0    64.0
# 129             68        20.0             0.0   52.0             0.0    64.0
# 141             68        20.0             0.0  826.0             0.0    64.0
# 183             68        20.0             0.0   52.0             0.0    64.0
# 242             68        20.0             0.0   83.0             0.0    64.0
# 243             68        20.0             0.0   52.0             0.0    64.0
# 245             68        20.0             0.0   52.0             0.0    64.0
# 247             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 70        6.0  ...               65535.0                0.0        2,4,8,1,3
# 75        6.0  ...                 343.0                0.0            1,1,8
# 76        6.0  ...                 343.0                0.0            1,1,8
# 88        6.0  ...                 354.0                0.0            1,1,8
# 90        6.0  ...                 365.0                0.0            1,1,8
# 92        6.0  ...                 377.0                0.0            1,1,8
# 94        6.0  ...                 386.0                0.0            1,1,8
# 96        6.0  ...                 386.0                0.0            1,1,8
# 100       6.0  ...                 386.0                0.0            1,1,8
# 129       6.0  ...                 396.0                0.0            1,1,8
# 141       6.0  ...                 396.0                0.0            1,1,8
# 183       6.0  ...                 406.0                0.0            1,1,8
# 242       6.0  ...                 406.0                0.0            1,1,8
# 243       6.0  ...                 406.0                0.0            1,1,8
# 245       6.0  ...                 406.0                0.0            1,1,8
# 247       6.0  ...                 406.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 70         4,2,10,3          NaN          NaN         NaN       TCP  44350.0
# 75               10          NaN          NaN         NaN       TCP  44350.0
# 76               10          NaN          NaN         NaN       TCP  44350.0
# 88               10          NaN          NaN         NaN       TCP  44350.0
# 90               10          NaN          NaN         NaN       TCP  44350.0
# 92               10          NaN          NaN         NaN       TCP  44350.0
# 94               10          NaN          NaN         NaN       TCP  44350.0
# 96               10          NaN          NaN         NaN       TCP  44350.0
# 100              10          NaN          NaN         NaN       TCP  44350.0
# 129              10          NaN          NaN         NaN       TCP  44350.0
# 141              10          NaN          NaN         NaN       TCP  44350.0
# 183              10          NaN          NaN         NaN       TCP  44350.0
# 242              10          NaN          NaN         NaN       TCP  44350.0
# 243              10          NaN          NaN         NaN       TCP  44350.0
# 245              10          NaN          NaN         NaN       TCP  44350.0
# 247              10          NaN          NaN         NaN       TCP  44350.0
#
#      dstport
# 70     443.0
# 75     443.0
# 76     443.0
# 88     443.0
# 90     443.0
# 92     443.0
# 94     443.0
# 96     443.0
# 100    443.0
# 129    443.0
# 141    443.0
# 183    443.0
# 242    443.0
# 243    443.0
# 245    443.0
# 247    443.0
#
# [16 rows x 28 columns]
# ('10.146.66.8', 44351.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 105           106  Apr 30, 2019 08:20:33.732860000 CDT         76
# 107           108  Apr 30, 2019 08:20:33.807599000 CDT         68
# 110           111  Apr 30, 2019 08:20:33.808292000 CDT        254
# 116           117  Apr 30, 2019 08:20:33.822392000 CDT         68
# 118           119  Apr 30, 2019 08:20:33.823093000 CDT         68
# 120           121  Apr 30, 2019 08:20:33.823155000 CDT         68
# 122           123  Apr 30, 2019 08:20:33.823205000 CDT         68
# 123           124  Apr 30, 2019 08:20:33.850503000 CDT        161
# 126           127  Apr 30, 2019 08:20:33.861700000 CDT        572
# 171           172  Apr 30, 2019 08:20:34.120307000 CDT         68
# 236           237  Apr 30, 2019 08:20:54.121742000 CDT         99
# 237           238  Apr 30, 2019 08:20:54.124274000 CDT         68
# 240           241  Apr 30, 2019 08:20:54.152612000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 105             76        20.0             0.0   60.0             0.0    64.0
# 107             68        20.0             0.0   52.0             0.0    64.0
# 110             68        20.0             0.0  238.0             0.0    64.0
# 116             68        20.0             0.0   52.0             0.0    64.0
# 118             68        20.0             0.0   52.0             0.0    64.0
# 120             68        20.0             0.0   52.0             0.0    64.0
# 122             68        20.0             0.0   52.0             0.0    64.0
# 123             68        20.0             0.0  145.0             0.0    64.0
# 126             68        20.0             0.0  556.0             0.0    64.0
# 171             68        20.0             0.0   52.0             0.0    64.0
# 236             68        20.0             0.0   83.0             0.0    64.0
# 237             68        20.0             0.0   52.0             0.0    64.0
# 240             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 105       6.0  ...               65535.0                0.0        2,4,8,1,3
# 107       6.0  ...                 343.0                0.0            1,1,8
# 110       6.0  ...                 343.0                0.0            1,1,8
# 116       6.0  ...                 354.0                0.0            1,1,8
# 118       6.0  ...                 365.0                0.0            1,1,8
# 120       6.0  ...                 377.0                0.0            1,1,8
# 122       6.0  ...                 386.0                0.0            1,1,8
# 123       6.0  ...                 386.0                0.0            1,1,8
# 126       6.0  ...                 386.0                0.0            1,1,8
# 171       6.0  ...                 396.0                0.0            1,1,8
# 236       6.0  ...                 396.0                0.0            1,1,8
# 237       6.0  ...                 396.0                0.0            1,1,8
# 240       6.0  ...                 396.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 105        4,2,10,3          NaN          NaN         NaN       TCP  44351.0
# 107              10          NaN          NaN         NaN       TCP  44351.0
# 110              10          NaN          NaN         NaN       TCP  44351.0
# 116              10          NaN          NaN         NaN       TCP  44351.0
# 118              10          NaN          NaN         NaN       TCP  44351.0
# 120              10          NaN          NaN         NaN       TCP  44351.0
# 122              10          NaN          NaN         NaN       TCP  44351.0
# 123              10          NaN          NaN         NaN       TCP  44351.0
# 126              10          NaN          NaN         NaN       TCP  44351.0
# 171              10          NaN          NaN         NaN       TCP  44351.0
# 236              10          NaN          NaN         NaN       TCP  44351.0
# 237              10          NaN          NaN         NaN       TCP  44351.0
# 240              10          NaN          NaN         NaN       TCP  44351.0
#
#      dstport
# 105    443.0
# 107    443.0
# 110    443.0
# 116    443.0
# 118    443.0
# 120    443.0
# 122    443.0
# 123    443.0
# 126    443.0
# 171    443.0
# 236    443.0
# 237    443.0
# 240    443.0
#
# [13 rows x 28 columns]
# ('10.146.66.8', 44352.0, '162.125.8.7', 443.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 134           135  Apr 30, 2019 08:20:33.944356000 CDT         76
# 137           138  Apr 30, 2019 08:20:33.953760000 CDT         68
# 138           139  Apr 30, 2019 08:20:33.954913000 CDT        257
# 145           146  Apr 30, 2019 08:20:33.966455000 CDT         68
# 147           148  Apr 30, 2019 08:20:33.967147000 CDT         68
# 149           150  Apr 30, 2019 08:20:33.967210000 CDT         68
# 151           152  Apr 30, 2019 08:20:33.967259000 CDT         68
# 153           154  Apr 30, 2019 08:20:33.992411000 CDT        161
# 155           156  Apr 30, 2019 08:20:34.003488000 CDT        849
# 195           196  Apr 30, 2019 08:20:34.263999000 CDT         68
# 249           250  Apr 30, 2019 08:20:54.265404000 CDT         99
# 250           251  Apr 30, 2019 08:20:54.266406000 CDT         68
# 252           253  Apr 30, 2019 08:20:54.282881000 CDT         68
# 254           255  Apr 30, 2019 08:20:54.283717000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn ip.len  ip.frag_offset  ip.ttl  \
# 134             76        20.0             0.0   60.0             0.0    64.0
# 137             68        20.0             0.0   52.0             0.0    64.0
# 138             68        20.0             0.0  241.0             0.0    64.0
# 145             68        20.0             0.0   52.0             0.0    64.0
# 147             68        20.0             0.0   52.0             0.0    64.0
# 149             68        20.0             0.0   52.0             0.0    64.0
# 151             68        20.0             0.0   52.0             0.0    64.0
# 153             68        20.0             0.0  145.0             0.0    64.0
# 155             68        20.0             0.0  833.0             0.0    64.0
# 195             68        20.0             0.0   52.0             0.0    64.0
# 249             68        20.0             0.0   83.0             0.0    64.0
# 250             68        20.0             0.0   52.0             0.0    64.0
# 252             68        20.0             0.0   52.0             0.0    64.0
# 254             68        20.0             0.0   52.0             0.0    64.0
#
#      ip.proto  ... tcp.window_size_value tcp.urgent_pointer  tcp.option_kind  \
# 134       6.0  ...               65535.0                0.0        2,4,8,1,3
# 137       6.0  ...                 343.0                0.0            1,1,8
# 138       6.0  ...                 343.0                0.0            1,1,8
# 145       6.0  ...                 354.0                0.0            1,1,8
# 147       6.0  ...                 365.0                0.0            1,1,8
# 149       6.0  ...                 377.0                0.0            1,1,8
# 151       6.0  ...                 386.0                0.0            1,1,8
# 153       6.0  ...                 386.0                0.0            1,1,8
# 155       6.0  ...                 386.0                0.0            1,1,8
# 195       6.0  ...                 396.0                0.0            1,1,8
# 249       6.0  ...                 396.0                0.0            1,1,8
# 250       6.0  ...                 396.0                0.0            1,1,8
# 252       6.0  ...                 396.0                0.0            1,1,8
# 254       6.0  ...                 396.0                0.0            1,1,8
#
#      tcp.option_len  udp.srcport  udp.dstport  udp.length  protocal  srcport  \
# 134        4,2,10,3          NaN          NaN         NaN       TCP  44352.0
# 137              10          NaN          NaN         NaN       TCP  44352.0
# 138              10          NaN          NaN         NaN       TCP  44352.0
# 145              10          NaN          NaN         NaN       TCP  44352.0
# 147              10          NaN          NaN         NaN       TCP  44352.0
# 149              10          NaN          NaN         NaN       TCP  44352.0
# 151              10          NaN          NaN         NaN       TCP  44352.0
# 153              10          NaN          NaN         NaN       TCP  44352.0
# 155              10          NaN          NaN         NaN       TCP  44352.0
# 195              10          NaN          NaN         NaN       TCP  44352.0
# 249              10          NaN          NaN         NaN       TCP  44352.0
# 250              10          NaN          NaN         NaN       TCP  44352.0
# 252              10          NaN          NaN         NaN       TCP  44352.0
# 254              10          NaN          NaN         NaN       TCP  44352.0
#
#      dstport
# 134    443.0
# 137    443.0
# 138    443.0
# 145    443.0
# 147    443.0
# 149    443.0
# 151    443.0
# 153    443.0
# 155    443.0
# 195    443.0
# 249    443.0
# 250    443.0
# 252    443.0
# 254    443.0
#
# [14 rows x 28 columns]
# ('10.146.66.8', 57342.0, '128.83.185.41', 53.0, 'UDP')
# ...
# 128             68        20.0             0.0    86.0             0.0
# 152             68        20.0             0.0    52.0             0.0
# 181             68        20.0             0.0   709.0             0.0
# 182             68        20.0             0.0    86.0             0.0
# 244             68        20.0             0.0    52.0             0.0
# 246             68        20.0             0.0    52.0             0.0
# 248             56        20.0             0.0    40.0             0.0
#
#      ip.ttl  ip.proto  ... tcp.window_size_value tcp.urgent_pointer  \
# 74     55.0       6.0  ...               28560.0                0.0
# 86     55.0       6.0  ...                  58.0                0.0
# 87     55.0       6.0  ...                  58.0                0.0
# 89     55.0       6.0  ...                  58.0                0.0
# 91     55.0       6.0  ...                  58.0                0.0
# 93     55.0       6.0  ...                  58.0                0.0
# 99     55.0       6.0  ...                  58.0                0.0
# 109    55.0       6.0  ...                  62.0                0.0
# 127    55.0       6.0  ...                  62.0                0.0
# 128    55.0       6.0  ...                  62.0                0.0
# 152    55.0       6.0  ...                  65.0                0.0
# 181    55.0       6.0  ...                  65.0                0.0
# 182    55.0       6.0  ...                  65.0                0.0
# 244    55.0       6.0  ...                  65.0                0.0
# 246    55.0       6.0  ...                  65.0                0.0
# 248    55.0       6.0  ...                   0.0                0.0
#
#      tcp.option_kind  tcp.option_len  udp.srcport  udp.dstport  udp.length  \
# 74         2,4,8,1,3        4,2,10,3          NaN          NaN         NaN
# 86             1,1,8              10          NaN          NaN         NaN
# 87             1,1,8              10          NaN          NaN         NaN
# 89             1,1,8              10          NaN          NaN         NaN
# 91             1,1,8              10          NaN          NaN         NaN
# 93             1,1,8              10          NaN          NaN         NaN
# 99             1,1,8              10          NaN          NaN         NaN
# 109            1,1,8              10          NaN          NaN         NaN
# 127            1,1,8              10          NaN          NaN         NaN
# 128            1,1,8              10          NaN          NaN         NaN
# 152            1,1,8              10          NaN          NaN         NaN
# 181            1,1,8              10          NaN          NaN         NaN
# 182            1,1,8              10          NaN          NaN         NaN
# 244            1,1,8              10          NaN          NaN         NaN
# 246            1,1,8              10          NaN          NaN         NaN
# 248              NaN             NaN          NaN          NaN         NaN
#
#      protocal  srcport  dstport
# 74        TCP    443.0  44350.0
# 86        TCP    443.0  44350.0
# 87        TCP    443.0  44350.0
# 89        TCP    443.0  44350.0
# 91        TCP    443.0  44350.0
# 93        TCP    443.0  44350.0
# 99        TCP    443.0  44350.0
# 109       TCP    443.0  44350.0
# 127       TCP    443.0  44350.0
# 128       TCP    443.0  44350.0
# 152       TCP    443.0  44350.0
# 181       TCP    443.0  44350.0
# 182       TCP    443.0  44350.0
# 244       TCP    443.0  44350.0
# 246       TCP    443.0  44350.0
# 248       TCP    443.0  44350.0
#
# [16 rows x 28 columns]
# ('162.125.8.7', 443.0, '10.146.66.8', 44351.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 106           107  Apr 30, 2019 08:20:33.807481000 CDT         76
# 113           114  Apr 30, 2019 08:20:33.817595000 CDT         68
# 115           116  Apr 30, 2019 08:20:33.822293000 CDT       1306
# 117           118  Apr 30, 2019 08:20:33.823024000 CDT       1306
# 119           120  Apr 30, 2019 08:20:33.823113000 CDT       1306
# 121           122  Apr 30, 2019 08:20:33.823170000 CDT        719
# 125           126  Apr 30, 2019 08:20:33.860096000 CDT        119
# 130           131  Apr 30, 2019 08:20:33.912287000 CDT         68
# 167           168  Apr 30, 2019 08:20:34.111181000 CDT       1114
# 168           169  Apr 30, 2019 08:20:34.111274000 CDT        102
# 238           239  Apr 30, 2019 08:20:54.149922000 CDT         68
# 239           240  Apr 30, 2019 08:20:54.152327000 CDT         68
# 241           242  Apr 30, 2019 08:20:54.152711000 CDT         68
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn  ip.len  ip.frag_offset  \
# 106             76        20.0             0.0    60.0             0.0
# 113             68        20.0             0.0    52.0             0.0
# 115             68        20.0             0.0  1290.0             0.0
# 117             68        20.0             0.0  1290.0             0.0
# 119             68        20.0             0.0  1290.0             0.0
# 121             68        20.0             0.0   703.0             0.0
# 125             68        20.0             0.0   103.0             0.0
# 130             68        20.0             0.0    52.0             0.0
# 167             68        20.0             0.0  1098.0             0.0
# 168             68        20.0             0.0    86.0             0.0
# 238             68        20.0             0.0    52.0             0.0
# 239             68        20.0             0.0    52.0             0.0
# 241             68        20.0             0.0    52.0             0.0
#
#      ip.ttl  ip.proto  ... tcp.window_size_value tcp.urgent_pointer  \
# 106    55.0       6.0  ...               28560.0                0.0
# 113    55.0       6.0  ...                  58.0                0.0
# 115    55.0       6.0  ...                  58.0                0.0
# 117    55.0       6.0  ...                  58.0                0.0
# 119    55.0       6.0  ...                  58.0                0.0
# 121    55.0       6.0  ...                  58.0                0.0
# 125    55.0       6.0  ...                  58.0                0.0
# 130    55.0       6.0  ...                  60.0                0.0
# 167    55.0       6.0  ...                  60.0                0.0
# 168    55.0       6.0  ...                  60.0                0.0
# 238    55.0       6.0  ...                  60.0                0.0
# 239    55.0       6.0  ...                  60.0                0.0
# 241    55.0       6.0  ...                  60.0                0.0
#
#      tcp.option_kind  tcp.option_len  udp.srcport  udp.dstport  udp.length  \
# 106        2,4,8,1,3        4,2,10,3          NaN          NaN         NaN
# 113            1,1,8              10          NaN          NaN         NaN
# 115            1,1,8              10          NaN          NaN         NaN
# 117            1,1,8              10          NaN          NaN         NaN
# 119            1,1,8              10          NaN          NaN         NaN
# 121            1,1,8              10          NaN          NaN         NaN
# 125            1,1,8              10          NaN          NaN         NaN
# 130            1,1,8              10          NaN          NaN         NaN
# 167            1,1,8              10          NaN          NaN         NaN
# 168            1,1,8              10          NaN          NaN         NaN
# 238            1,1,8              10          NaN          NaN         NaN
# 239            1,1,8              10          NaN          NaN         NaN
# 241            1,1,8              10          NaN          NaN         NaN
#
#      protocal  srcport  dstport
# 106       TCP    443.0  44351.0
# 113       TCP    443.0  44351.0
# 115       TCP    443.0  44351.0
# 117       TCP    443.0  44351.0
# 119       TCP    443.0  44351.0
# 121       TCP    443.0  44351.0
# 125       TCP    443.0  44351.0
# 130       TCP    443.0  44351.0
# 167       TCP    443.0  44351.0
# 168       TCP    443.0  44351.0
# 238       TCP    443.0  44351.0
# 239       TCP    443.0  44351.0
# 241       TCP    443.0  44351.0
#
# [13 rows x 28 columns]
# ('162.125.8.7', 443.0, '10.146.66.8', 44352.0, 'TCP')
#      frame.number                           frame.time  frame.len  \
# 136           137  Apr 30, 2019 08:20:33.953642000 CDT         76
# 142           143  Apr 30, 2019 08:20:33.963794000 CDT         68
# 144           145  Apr 30, 2019 08:20:33.966374000 CDT       1306
# 146           147  Apr 30, 2019 08:20:33.967077000 CDT       1306
# 148           149  Apr 30, 2019 08:20:33.967167000 CDT       1306
# 150           151  Apr 30, 2019 08:20:33.967224000 CDT        719
# 154           155  Apr 30, 2019 08:20:34.001916000 CDT        119
# 163           164  Apr 30, 2019 08:20:34.060367000 CDT         68
# 193           194  Apr 30, 2019 08:20:34.257311000 CDT        595
# 194           195  Apr 30, 2019 08:20:34.257457000 CDT        102
# 251           252  Apr 30, 2019 08:20:54.282575000 CDT         68
# 253           254  Apr 30, 2019 08:20:54.283470000 CDT         68
# 255           256  Apr 30, 2019 08:20:54.293858000 CDT         62
#
#      frame.cap_len  ip.hdr_len  ip.dsfield.ecn  ip.len  ip.frag_offset  \
# 136             76        20.0             0.0    60.0             0.0
# 142             68        20.0             0.0    52.0             0.0
# 144             68        20.0             0.0  1290.0             0.0
# 146             68        20.0             0.0  1290.0             0.0
# 148             68        20.0             0.0  1290.0             0.0
# 150             68        20.0             0.0   703.0             0.0
# 154             68        20.0             0.0   103.0             0.0
# 163             68        20.0             0.0    52.0             0.0
# 193             68        20.0             0.0   579.0             0.0
# 194             68        20.0             0.0    86.0             0.0
# 251             68        20.0             0.0    52.0             0.0
# 253             68        20.0             0.0    52.0             0.0
# 255             56        20.0             0.0    40.0             0.0
#
#      ip.ttl  ip.proto  ... tcp.window_size_value tcp.urgent_pointer  \
# 136    55.0       6.0  ...               28560.0                0.0
# 142    55.0       6.0  ...                  58.0                0.0
# 144    55.0       6.0  ...                  58.0                0.0
# 146    55.0       6.0  ...                  58.0                0.0
# 148    55.0       6.0  ...                  58.0                0.0
# 150    55.0       6.0  ...                  58.0                0.0
# 154    55.0       6.0  ...                  58.0                0.0
# 163    55.0       6.0  ...                  61.0                0.0
# 193    55.0       6.0  ...                  61.0                0.0
# 194    55.0       6.0  ...                  61.0                0.0
# 251    55.0       6.0  ...                  61.0                0.0
# 253    55.0       6.0  ...                  61.0                0.0
# 255    55.0       6.0  ...                   0.0                0.0
#
#      tcp.option_kind  tcp.option_len  udp.srcport  udp.dstport  udp.length  \
# 136        2,4,8,1,3        4,2,10,3          NaN          NaN         NaN
# 142            1,1,8              10          NaN          NaN         NaN
# 144            1,1,8              10          NaN          NaN         NaN
# 146            1,1,8              10          NaN          NaN         NaN
# 148            1,1,8              10          NaN          NaN         NaN
# 150            1,1,8              10          NaN          NaN         NaN
# 154            1,1,8              10          NaN          NaN         NaN
# 163            1,1,8              10          NaN          NaN         NaN
# 193            1,1,8              10          NaN          NaN         NaN
# 194            1,1,8              10          NaN          NaN         NaN
# 251            1,1,8              10          NaN          NaN         NaN
# 253            1,1,8              10          NaN          NaN         NaN
# 255              NaN             NaN          NaN          NaN         NaN
#
#      protocal  srcport  dstport
# 136       TCP    443.0  44352.0
# 142       TCP    443.0  44352.0
# 144       TCP    443.0  44352.0
# 146       TCP    443.0  44352.0
# 148       TCP    443.0  44352.0
# 150       TCP    443.0  44352.0
# 154       TCP    443.0  44352.0
# 163       TCP    443.0  44352.0
# 193       TCP    443.0  44352.0
# 194       TCP    443.0  44352.0
# 251       TCP    443.0  44352.0
# 253       TCP    443.0  44352.0
# 255       TCP    443.0  44352.0
#
# [13 rows x 28 columns]
# {'ul_total_num_pkts': 12, 'ul_total_num_bytes': 1853.0, 'ul_min_pkt_size': 52.0, 'ul_max_pkt_size': 830.0, 'ul_mean_pkt_size': 154.41666666666666, 'ul_std_pkt_size': 221.10732002739525, 'ul_min_iat': 4.7e-05, 'ul_max_iat': 7.504696, 'ul_mean_iat': 0.7109043636363637, 'ul_std_iat': 2.2534104784651316, 'ul_dur': 7.819948, 'dl_total_num_pkts': 10, 'dl_total_num_bytes': 4334.0, 'dl_min_pkt_size': 52.0, 'dl_max_pkt_size': 1290.0, 'dl_mean_pkt_size': 433.4, 'dl_std_pkt_size': 530.9482502508549, 'dl_min_iat': 5.8e-05, 'dl_max_iat': 7.642004, 'dl_mean_iat': 0.8751036666666666, 'dl_std_iat': 2.5378151189099647, 'dl_dur': 7.875933, 'ip_A': '10.146.66.8', 'port_A': 37879.0, 'ip_B': '162.125.18.133', 'port_B': 443.0, 'protocal': 'TCP'}
# If using all scalar values, you must pass an index
#
#  Error while processing dropbox_upload_2019-04-30_08-20-32_5bd0c615.csv.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 15
#      14 try:
# ---> 15     df_flow = process_df_by_flow(df)
#      16     df_flow['action'] = action
#
# Cell In[16], line 78, in process_df_by_flow(df)
#      77             print(bi_flow_features)
# ---> 78             df_flow = pd.concat([df_flow,pd.DataFrame(bi_flow_features)],ignore_index= True)#df_flow.append(bi_flow_features, ignore_index=True)
#      79 return df_flow
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     113 if index is None:
# --> 114     index = _extract_index(arrays)
#     115 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:667, in _extract_index(data)
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#
# ValueError: If using all scalar values, you must pass an index
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 23
#      21         integrity = False
#      22         print('\n Error while processing {}. \n'.format(fname))
# ---> 23         assert False
#      25 df_app['app'] = app
#      27 if integrity:
#
# AssertionError:

# %%
# Out:
# 0
